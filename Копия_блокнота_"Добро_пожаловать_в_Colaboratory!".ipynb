# %% [markdown]
# <a href="https://colab.research.google.com/github/Garegianin/WebProgrammy/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%94%D0%BE%D0%B1%D1%80%D0%BE_%D0%BF%D0%BE%D0%B6%D0%B0%D0%BB%D0%BE%D0%B2%D0%B0%D1%82%D1%8C_%D0%B2_Colaboratory!%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
response = requests.get('https://api.spending.gov.ru/v1/natprojects/contracts?fp_id=E4')
print(response)
# Out:
# <Response [200]>

# %%
contracts = response.json()
print(contracts['total'])
# Out:
# 348

# %%
contracts
# Out:
# {'count': 50,
#  'items': [{'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 2895911.83,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 2895911.83,
#    'load_id': 236416,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 2895911.83}],
#    'products': [{'name': 'Принтер',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 14850.82,
#      'quantity': 194.0},
#     {'name': 'Принтер',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 14852.75,
#      'quantity': 1.0}],
#    'regnum': '2312331699419000011',
#    'relevant_price': 2895911.83,
#    'sign_date': '2019-02-09T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000011',
#    'suppliers': [{'supplier_inn': '3123314130',
#      'supplier_kpp': '312301001',
#      'supplier_name': 'ООО "РЕСУРС-МЕДИА"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000011'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'ET',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 5261100.0,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 5261100.0,
#    'load_id': 236066,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 5261100.0}],
#    'products': [{'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 26980.0,
#      'quantity': 195.0}],
#    'regnum': '2312331699419000010',
#    'relevant_price': 5261100.0,
#    'sign_date': '2019-02-11T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000010',
#    'suppliers': [{'supplier_inn': '7716870664',
#      'supplier_kpp': '771601001',
#      'supplier_name': 'ООО "ИК ФОРСИС"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000010'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'ET',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 5502535.16,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 5502535.16,
#    'load_id': 236066,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 5502535.16}],
#    'products': [{'name': 'Портативная проекционная система в комплекте с кронштейном и кабелем',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.16.190',
#      'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#      'price': 28218.12,
#      'quantity': 194.0},
#     {'name': 'Портативная проекционная система в комплекте с кронштейном и кабелем',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.16.190',
#      'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#      'price': 28219.88,
#      'quantity': 1.0}],
#    'regnum': '2312331699419000009',
#    'relevant_price': 5502535.16,
#    'sign_date': '2019-02-11T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000009',
#    'suppliers': [{'supplier_inn': '6623127510',
#      'supplier_kpp': '662301001',
#      'supplier_name': 'ООО "Консалтинговая группа Овечкин и партнеры"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000009'},
#   {'budget_code': '90020067',
#    'budget_level_code': '2',
#    'budget_name': 'Окружной бюджет',
#    'contract_stage': 'E',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '8901025527',
#    'customer_kpp': '890101001',
#    'customer_name': 'ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#    'customer_spz': '08902000003',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 2800000.0,
#      'grbs_code': '875',
#      'grbs_name': None,
#      'kbk': '8750709023E412440244'}],
#    'full_price': 2800000.0,
#    'load_id': 253965,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 2800000.0}],
#    'products': [{'name': 'Выполнение работ по разработке системы персонифицированного финансирования дополнительного образования в Ямало-Ненецком автономном округе, предусмотренных мероприятием 2.2.4 Выполнение работ по развитию и технической поддержке информационных систем в сфере образования. Государственной программы ЯНАО «Информационное общество на 2014-2021 гг.»',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': '58.29.50.000',
#      'okpd2_name': 'Услуги по предоставлению лицензий на право использовать компьютерное программное обеспечение',
#      'price': 2800000.0,
#      'quantity': 1.0}],
#    'regnum': '2890102552719000007',
#    'relevant_price': 2800000.0,
#    'sign_date': '2019-03-29T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2890102552719000007',
#    'suppliers': [{'supplier_inn': '5018197685',
#      'supplier_kpp': '501801001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНСТИТУТ РАЗВИТИЯ ПЕРСОНИФИЦИРОВАННЫХ СИСТЕМ УПРАВЛЕНИЯ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2890102552719000007'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 591317.0,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 591317.0,
#    'load_id': 257934,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 591317.0}],
#    'products': [{'name': 'Экран для проектора',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.17.150',
#      'okpd2_name': 'Экраны проекционные',
#      'price': 3032.39,
#      'quantity': 194.0},
#     {'name': 'Экран для проектора',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.17.150',
#      'okpd2_name': 'Экраны проекционные',
#      'price': 3033.34,
#      'quantity': 1.0}],
#    'regnum': '2312331699419000007',
#    'relevant_price': 591317.0,
#    'sign_date': '2019-01-21T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000007',
#    'suppliers': [{'supplier_inn': '5404066353',
#      'supplier_kpp': '000000000',
#      'supplier_name': 'Индивидуальный предприниматель Мезенина Аксана Васильевна'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000007'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 10866245.5,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 10866245.5,
#    'load_id': 261505,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 10866245.5}],
#    'products': [{'name': 'Принтер',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 12306.05,
#      'quantity': 882.0},
#     {'name': 'Принтер',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 12309.4,
#      'quantity': 1.0}],
#    'regnum': '2312331699419000014',
#    'relevant_price': 10866245.5,
#    'sign_date': '2019-04-04T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000014',
#    'suppliers': [{'supplier_inn': '3123331167',
#      'supplier_kpp': '312301001',
#      'supplier_name': 'ООО "ЛЛС ГРУПП"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000014'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 23143961.3,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 23143961.3,
#    'load_id': 271949,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 23143961.3}],
#    'products': [{'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 20391.15,
#      'quantity': 1134.0},
#     {'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 20397.2,
#      'quantity': 1.0}],
#    'regnum': '2312331699419000020',
#    'relevant_price': 23143961.3,
#    'sign_date': '2019-04-15T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000020',
#    'suppliers': [{'supplier_inn': '3123331167',
#      'supplier_kpp': '312301001',
#      'supplier_name': 'ООО "ЛЛС ГРУПП"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000020'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 1403664.0,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 1403664.0,
#    'load_id': 262582,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 1403664.0}],
#    'products': [{'name': 'экран для проектора',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.17.150',
#      'okpd2_name': 'Экраны проекционные',
#      'price': 2085.68,
#      'quantity': 672.0},
#     {'name': 'экран для проектора',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.17.150',
#      'okpd2_name': 'Экраны проекционные',
#      'price': 2087.04,
#      'quantity': 1.0}],
#    'regnum': '2312331699419000031',
#    'relevant_price': 1403664.0,
#    'sign_date': '2019-04-29T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000031',
#    'suppliers': [{'supplier_inn': '3123445340',
#      'supplier_kpp': '312301001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЕОСТАН"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000031'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 4427215.65,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 4427215.65,
#    'load_id': 265011,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 4427215.65}],
#    'products': [{'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 22703.67,
#      'quantity': 195.0}],
#    'regnum': '2312331699419000036',
#    'relevant_price': 4427215.65,
#    'sign_date': '2019-05-07T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000036',
#    'suppliers': [{'supplier_inn': '3123331167',
#      'supplier_kpp': '312301001',
#      'supplier_name': 'ООО "ЛЛС ГРУПП"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000036'},
#   {'budget_code': '90020067',
#    'budget_level_code': '2',
#    'budget_name': 'Окружной бюджет',
#    'contract_stage': 'E',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '8901025527',
#    'customer_kpp': '890101001',
#    'customer_name': 'ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#    'customer_spz': '08902000003',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 3960000.0,
#      'grbs_code': '875',
#      'grbs_name': None,
#      'kbk': '8750709023E412440244'}],
#    'full_price': 3960000.0,
#    'load_id': 270416,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 3960000.0}],
#    'products': [{'name': 'Оказание услуг по технической поддержке действующих в Ямало-Ненецком автономном округе автоматизированных информационных систем в сфере образования',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': '58.29.50.000',
#      'okpd2_name': 'Услуги по предоставлению лицензий на право использовать компьютерное программное обеспечение',
#      'price': 3960000.0,
#      'quantity': 1.0}],
#    'regnum': '2890102552719000012',
#    'relevant_price': 3960000.0,
#    'sign_date': '2019-05-20T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2890102552719000012',
#    'suppliers': [{'supplier_inn': '6311093270',
#      'supplier_kpp': '631101001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИРСОФТ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2890102552719000012'},
#   {'budget_code': '69020002',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Челябинской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '7447041828',
#    'customer_kpp': '745301001',
#    'customer_name': 'ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "ЧЕЛЯБИНСКИЙ ИНСТИТУТ ПЕРЕПОДГОТОВКИ И ПОВЫШЕНИЯ КВАЛИФИКАЦИИ РАБОТНИКОВ ОБРАЗОВАНИЯ"',
#    'customer_spz': '03692000088',
#    'fp_ids': ['E2', 'E4'],
#    'fp_info': [{'fp_id': 'E2',
#      'fp_price': 10746.0,
#      'grbs_code': '012',
#      'grbs_name': None,
#      'kbk': '0120705030E203180244'},
#     {'fp_id': 'E4',
#      'fp_price': 3223.8,
#      'grbs_code': '012',
#      'grbs_name': None,
#      'kbk': '0120705030E403190244'}],
#    'full_price': 53732.14,
#    'load_id': 274565,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 13969.8}],
#    'products': [{'name': 'Бумага для офисной техники',
#      'okei_code': '778',
#      'okei_name': 'Упаковка',
#      'okpd2_code': '17.12.14.119',
#      'okpd2_name': 'Бумага для печати прочая',
#      'price': 214.92,
#      'quantity': 249.0},
#     {'name': 'Бумага для офисной техники',
#      'okei_code': '778',
#      'okei_name': 'Упаковка',
#      'okpd2_code': '17.12.14.119',
#      'okpd2_name': 'Бумага для печати прочая',
#      'price': 217.06,
#      'quantity': 1.0}],
#    'regnum': '2744704182819000798',
#    'relevant_price': 13969.8,
#    'sign_date': '2019-06-03T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2744704182819000798',
#    'suppliers': [{'supplier_inn': '7448122237',
#      'supplier_kpp': '744801001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕДЕНТ Ч"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2744704182819000798'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 27923448.0,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 27923448.0,
#    'load_id': 275420,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 27923448.0}],
#    'products': [{'name': 'Портативная проекционная система в комплекте с кронштейном и кабелем',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.16.190',
#      'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#      'price': 32774.0,
#      'quantity': 852.0}],
#    'regnum': '2312331699419000042',
#    'relevant_price': 27923448.0,
#    'sign_date': '2019-06-07T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000042',
#    'suppliers': [{'supplier_inn': '7727845469',
#      'supplier_kpp': '772701001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЕТРА"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000042'},
#   {'budget_code': '99010001',
#    'budget_level_code': '1',
#    'budget_name': 'Федеральный бюджет',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '0711033902',
#    'customer_kpp': '072501001',
#    'customer_name': 'МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ, НАУКИ И ПО ДЕЛАМ МОЛОДЕЖИ КАБАРДИНО-БАЛКАРСКОЙ РЕСПУБЛИКИ',
#    'customer_spz': '01042000007',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 3256200.0,
#      'grbs_code': '973',
#      'grbs_name': None,
#      'kbk': '9730709022E452100244'}],
#    'full_price': 3256200.0,
#    'load_id': 278797,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 3256200.0}],
#    'products': [{'name': 'поставка учебного оборудования (Конструктор для практико-ориентированного изучения устройства и принципов работы механических моделей)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '32.99.53.130',
#      'okpd2_name': 'Приборы, аппаратура и устройства учебные демонстрационные',
#      'price': 40200.0,
#      'quantity': 81.0}],
#    'regnum': '2071103390219000011',
#    'relevant_price': 3256200.0,
#    'sign_date': '2019-06-06T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2071103390219000011',
#    'suppliers': [{'supplier_inn': '0909009071',
#      'supplier_kpp': '090901001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СЕЛЕНА"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2071103390219000011'},
#   {'budget_code': '26020001',
#    'budget_level_code': '2',
#    'budget_name': 'Бюджет Белгородской области',
#    'contract_stage': 'EC',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '3123316994',
#    'customer_kpp': '312301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#    'customer_spz': '01262000034',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 5065800.18,
#      'grbs_code': '810',
#      'grbs_name': None,
#      'kbk': '8100702022E4E0000242'}],
#    'full_price': 5065800.18,
#    'load_id': 281319,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 5065800.18}],
#    'products': [{'name': 'Портативные проекционные системы в комплекте с кронштейном и кабелем для нужд общеобразовательных организаций Белгородской области',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.16.190',
#      'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#      'price': 25978.46,
#      'quantity': 194.0},
#     {'name': 'Портативные проекционные системы в комплекте с кронштейном и кабелем для нужд общеобразовательных организаций Белгородской области',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.70.16.190',
#      'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#      'price': 25978.94,
#      'quantity': 1.0}],
#    'regnum': '2312331699419000044',
#    'relevant_price': 5065800.18,
#    'sign_date': '2019-06-24T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000044',
#    'suppliers': [{'supplier_inn': '7718825353',
#      'supplier_kpp': '771801001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕНТА"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000044'},
#   {'budget_code': '39020004',
#    'budget_level_code': '2',
#    'budget_name': 'областной бюджет',
#    'contract_stage': 'ET',
#    'contract_subject': None,
#    'currency': 'RUB',
#    'customer_inn': '4205123000',
#    'customer_kpp': '420501001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ КЕМЕРОВСКОЙ ОБЛАСТИ',
#    'customer_spz': '01392000019',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 104174784.0,
#      'grbs_code': '012',
#      'grbs_name': None,
#      'kbk': '0120709101E452100242'}],
#    'full_price': 104174784.0,
#    'load_id': 282750,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 104174784.0}],
#    'products': [{'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 52992.0,
#      'quantity': 98.0},
#     {'name': 'Ноутбук мобильного класса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 34080.0,
#      'quantity': 1470.0},
#     {'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 50784.0,
#      'quantity': 294.0},
#     {'name': 'Доставка и монтаж',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': '33.20.29.000',
#      'okpd2_name': 'Услуги по монтажу прочего оборудования общего назначения, не включенного в другие группировки',
#      'price': 5760.0,
#      'quantity': 49.0},
#     {'name': 'Вычислительный блок интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.40.110',
#      'okpd2_name': 'Устройства и блоки питания вычислительных машин',
#      'price': 33072.0,
#      'quantity': 98.0},
#     {'name': 'МФУ',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.18.000',
#      'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#      'price': 16224.0,
#      'quantity': 49.0},
#     {'name': 'Интерактивный комплекс',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.16.160',
#      'okpd2_name': 'Устройства ввода сенсорные',
#      'price': 302400.0,
#      'quantity': 98.0}],
#    'regnum': '2420512300019000055',
#    'relevant_price': 104174784.0,
#    'sign_date': '2019-06-27T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2420512300019000055',
#    'suppliers': [{'supplier_inn': '7707049388',
#      'supplier_kpp': '420543001',
#      'supplier_name': 'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РОСТЕЛЕКОМ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2420512300019000055'},
#   {'budget_code': '67020319',
#    'budget_level_code': '2',
#    'budget_name': 'Областной бюджет',
#    'contract_stage': 'E',
#    'contract_subject': 'Оказание услуг по доступу к информационно-коммуникационной сети Интернет',
#    'currency': 'RUB',
#    'customer_inn': '7202190205',
#    'customer_kpp': '720301001',
#    'customer_name': 'ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ТЮМЕНСКОЙ ОБЛАСТИ "ЦЕНТР ИНФОРМАЦИОННЫХ ТЕХНОЛОГИЙ ТЮМЕНСКОЙ ОБЛАСТИ"',
#    'customer_spz': '03672000068',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 102336.0,
#      'grbs_code': '159',
#      'grbs_name': None,
#      'kbk': '1590410530E415520242'}],
#    'full_price': 289952.0,
#    'load_id': 317225,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 102336.0}],
#    'products': [{'name': 'Услуги по доступу к информационно-коммуникационной сети Интернет',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 7072.0,
#      'quantity': 41.0}],
#    'regnum': '2720219020519000015',
#    'relevant_price': 102336.0,
#    'sign_date': '2019-04-02T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2720219020519000015',
#    'suppliers': [{'supplier_inn': '7707049388',
#      'supplier_kpp': '668543001',
#      'supplier_name': 'Публичное акционерное общество "Ростелеком"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2720219020519000015'},
#   {'budget_code': '09020936',
#    'budget_level_code': '2',
#    'budget_name': 'Республиканский бюджет Республики Мордовия',
#    'contract_stage': 'EC',
#    'contract_subject': 'поставка компьютерного и интерактивного оборудования',
#    'currency': 'RUB',
#    'customer_inn': '1326047197',
#    'customer_kpp': '132601001',
#    'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ РЕСПУБЛИКИ МОРДОВИЯ',
#    'customer_spz': '01092000013',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 18063880.0,
#      'grbs_code': '809',
#      'grbs_name': None,
#      'kbk': '8090709022E452100244'}],
#    'full_price': 18063880.0,
#    'load_id': 298943,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 18063880.0}],
#    'products': [{'name': 'МФУ (принтер, сканер, копир)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.18.000',
#      'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#      'price': 17485.0,
#      'quantity': 8.0},
#     {'name': 'Ноутбук для управленческого персонала',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 65250.0,
#      'quantity': 48.0},
#     {'name': 'Ноутбук учителя',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 76500.0,
#      'quantity': 16.0},
#     {'name': 'Ноутбук мобильного класса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 35500.0,
#      'quantity': 240.0},
#     {'name': 'Интерактивный комплекс',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.16.160',
#      'okpd2_name': 'Устройства ввода сенсорные',
#      'price': 315500.0,
#      'quantity': 16.0}],
#    'regnum': '2132604719719000008',
#    'relevant_price': 18063880.0,
#    'sign_date': '2019-07-03T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2132604719719000008',
#    'suppliers': [{'supplier_inn': '1326251273',
#      'supplier_kpp': '132601001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СМАРТ ГРУПП"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2132604719719000008'},
#   {'budget_code': '67020319',
#    'budget_level_code': '2',
#    'budget_name': 'Областной бюджет',
#    'contract_stage': 'EC',
#    'contract_subject': 'Поставка комплектов оборудования для внедрения целевой модели цифровой образовательной среды',
#    'currency': 'RUB',
#    'customer_inn': '7202137498',
#    'customer_kpp': '720301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ТЮМЕНСКОЙ ОБЛАСТИ',
#    'customer_spz': '01672000003',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 84736666.5,
#      'grbs_code': '013',
#      'grbs_name': None,
#      'kbk': '0130709600E410008242'}],
#    'full_price': 84736666.5,
#    'load_id': 299179,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 84736666.5}],
#    'products': [{'name': 'Комплект оборудования для внедрения целевой модели \nцифровой образовательной среды',
#      'okei_code': '839',
#      'okei_name': 'Комплект',
#      'okpd2_code': '32.99.53.130',
#      'okpd2_name': 'Приборы, аппаратура и устройства учебные демонстрационные',
#      'price': 2824555.55,
#      'quantity': 30.0}],
#    'regnum': '2720213749819000019',
#    'relevant_price': 84736666.5,
#    'sign_date': '2019-07-03T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2720213749819000019',
#    'suppliers': [{'supplier_inn': '7728734000',
#      'supplier_kpp': '772501001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТЛАЙН ПРОЕКТЫ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2720213749819000019'},
#   {'budget_code': '90020067',
#    'budget_level_code': '2',
#    'budget_name': 'Окружной бюджет',
#    'contract_stage': 'E',
#    'contract_subject': 'Выполнение работ по доработке региональной информационной системы управления сферой образования Ямало-Ненецкого автономного округа по расчету показателей доступности дошкольного образования',
#    'currency': 'RUB',
#    'customer_inn': '8901025527',
#    'customer_kpp': '890101001',
#    'customer_name': 'ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#    'customer_spz': '08902000003',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 3500000.0,
#      'grbs_code': '875',
#      'grbs_name': None,
#      'kbk': '8750709023E412440244'}],
#    'full_price': 3500000.0,
#    'load_id': 299215,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 3500000.0}],
#    'products': [{'name': 'Выполнение работ по доработке региональной информационной системы управления сферой образования Ямало-Ненецкого автономного округа по расчету показателей доступности дошкольного образования',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': '58.29.50.000',
#      'okpd2_name': 'Услуги по предоставлению лицензий на право использовать компьютерное программное обеспечение',
#      'price': 3500000.0,
#      'quantity': 1.0}],
#    'regnum': '2890102552719000021',
#    'relevant_price': 3500000.0,
#    'sign_date': '2019-07-10T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2890102552719000021',
#    'suppliers': [{'supplier_inn': '6311102655',
#      'supplier_kpp': '631101001',
#      'supplier_name': 'АКЦИОНЕРНОЕ ОБЩЕСТВО "ИРТЕХ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2890102552719000021'},
#   {'budget_code': '10020001',
#    'budget_level_code': '2',
#    'budget_name': 'Республиканский бюджет Республики Северная Осетия-Алания',
#    'contract_stage': 'EC',
#    'contract_subject': 'Поставка оборудования для внедрения целевой модели цифровой среды в общеобразовательных организациях и профессиональных образовательных организациях',
#    'currency': 'RUB',
#    'customer_inn': '1515906542',
#    'customer_kpp': '151301001',
#    'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ СЕВЕРНАЯ ОСЕТИЯ-АЛАНИЯ',
#    'customer_spz': '03102000007',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 20147950.2,
#      'grbs_code': '738',
#      'grbs_name': None,
#      'kbk': '738070209ИE452100242'}],
#    'full_price': 20147950.2,
#    'load_id': 314219,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 20147950.2}],
#    'products': [{'name': 'МФУ (принтер, сканер, копир)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.18.000',
#      'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#      'price': 19099.0,
#      'quantity': 20.0},
#     {'name': 'Ноутбук мобильного класса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 24881.05,
#      'quantity': 300.0},
#     {'name': 'Мобильное крепление для интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.40.190',
#      'okpd2_name': 'Комплектующие и запасные части для вычислительных машин прочие, не включенные в другие группировки',
#      'price': 13200.0,
#      'quantity': 20.0},
#     {'name': 'Ноутбук учителя',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 58797.76,
#      'quantity': 30.0},
#     {'name': 'Интерактивный комплекс',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.16.160',
#      'okpd2_name': 'Устройства ввода сенсорные',
#      'price': 277200.0,
#      'quantity': 20.0},
#     {'name': 'Вычислительный блок интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 46200.0,
#      'quantity': 20.0},
#     {'name': 'Ноутбук для управленческого персонала',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 47571.53,
#      'quantity': 80.0}],
#    'regnum': '2151590654219000015',
#    'relevant_price': 20147950.2,
#    'sign_date': '2019-07-09T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2151590654219000015',
#    'suppliers': [{'supplier_inn': '3257003993',
#      'supplier_kpp': '773001001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНТ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2151590654219000015'},
#   {'budget_code': '99010001',
#    'budget_level_code': '1',
#    'budget_name': 'Федеральный бюджет',
#    'contract_stage': 'EC',
#    'contract_subject': 'поставка компьютерной техники',
#    'currency': 'RUB',
#    'customer_inn': '0711033902',
#    'customer_kpp': '072501001',
#    'customer_name': 'МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ, НАУКИ И ПО ДЕЛАМ МОЛОДЕЖИ КАБАРДИНО-БАЛКАРСКОЙ РЕСПУБЛИКИ',
#    'customer_spz': '01042000007',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 34580809.9,
#      'grbs_code': '973',
#      'grbs_name': None,
#      'kbk': '9730709022E452100242'}],
#    'full_price': 34580809.9,
#    'load_id': 298919,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 34580809.9}],
#    'products': [{'name': 'МФУ',
#      'okei_code': '839',
#      'okei_name': 'Комплект',
#      'okpd2_code': '26.20.18.000',
#      'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#      'price': 35649.42,
#      'quantity': 15.0},
#     {'name': 'ноутбук (учителя)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 39622.4,
#      'quantity': 32.0},
#     {'name': 'интерактивный комплекс',
#      'okei_code': '839',
#      'okei_name': 'Комплект',
#      'okpd2_code': '26.20.16.190',
#      'okpd2_name': 'Устройства ввода/вывода данных прочие',
#      'price': 209250.0,
#      'quantity': 32.0},
#     {'name': 'ноутбук (для управленческого персонала)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 39622.4,
#      'quantity': 96.0},
#     {'name': 'вычислительный блок интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.13.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые, содержащие в одном корпусе центральный процессор и устройство ввода и вывода, объединенные или нет для автоматической обработки данных',
#      'price': 77500.0,
#      'quantity': 32.0},
#     {'name': 'ноутбук (мобильного класса)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 39622.4,
#      'quantity': 480.0},
#     {'name': 'мобильное крепление для интерактивного комплекса',
#      'okei_code': '839',
#      'okei_name': 'Комплект',
#      'okpd2_code': '26.20.40.190',
#      'okpd2_name': 'Комплектующие и запасные части для вычислительных машин прочие, не включенные в другие группировки',
#      'price': 23250.0,
#      'quantity': 32.0},
#     {'name': 'МФУ',
#      'okei_code': '839',
#      'okei_name': 'Комплект',
#      'okpd2_code': '26.20.18.000',
#      'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#      'price': 35649.4,
#      'quantity': 1.0}],
#    'regnum': '2071103390219000021',
#    'relevant_price': 34580809.9,
#    'sign_date': '2019-07-17T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2071103390219000021',
#    'suppliers': [{'supplier_inn': '0700000310',
#      'supplier_kpp': '072501001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КАББАЛКМЕСТПРОМ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2071103390219000021'},
#   {'budget_code': '94020233',
#    'budget_level_code': '2',
#    'budget_name': 'республиканский бюджет',
#    'contract_stage': 'E',
#    'contract_subject': 'Поставка средств информатизации и автоматизации образовательных процессов',
#    'currency': 'RUB',
#    'customer_inn': '2020001415',
#    'customer_kpp': '201401001',
#    'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#    'customer_spz': '01942000035',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 205983963.44,
#      'grbs_code': '205',
#      'grbs_name': None,
#      'kbk': '2050709029E45210Q244'}],
#    'full_price': 205983963.44,
#    'load_id': 298971,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 205983963.44}],
#    'products': [{'name': 'Ноутбук учителя',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 60637.0,
#      'quantity': 188.0},
#     {'name': 'МФУ (принтер, сканер, копир)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 16172.0,
#      'quantity': 94.0},
#     {'name': 'Ноутбук мобильного класса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 34644.0,
#      'quantity': 2820.0},
#     {'name': 'Мобильное крепление для интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 15342.51,
#      'quantity': 188.0},
#     {'name': 'Вычислительный блок интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 106222.87,
#      'quantity': 188.0},
#     {'name': 'Ноутбук для управленческого персонала',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 51337.0,
#      'quantity': 564.0},
#     {'name': 'Интерактивный комплекс',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 231700.0,
#      'quantity': 188.0}],
#    'regnum': '2202000141519000087',
#    'relevant_price': 205983963.44,
#    'sign_date': '2019-07-22T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2202000141519000087',
#    'suppliers': [{'supplier_inn': '7731351078',
#      'supplier_kpp': '773101001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2202000141519000087'},
#   {'budget_code': '24020001',
#    'budget_level_code': '2',
#    'budget_name': 'Областной бюджет',
#    'contract_stage': 'E',
#    'contract_subject': 'Комплект компьютерного и интерактивного оборудования',
#    'currency': 'RUB',
#    'customer_inn': '2901185216',
#    'customer_kpp': '290101001',
#    'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АРХАНГЕЛЬСКОЙ ОБЛАСТИ',
#    'customer_spz': '01242000015',
#    'fp_ids': ['E1', 'E4'],
#    'fp_info': [{'fp_id': 'E1',
#      'fp_price': 25379236.15,
#      'grbs_code': '075',
#      'grbs_name': 'Министерство науки и высшего образования Российской Федерации',
#      'kbk': '0750702021E151690244'},
#     {'fp_id': 'E4',
#      'fp_price': 28934943.88,
#      'grbs_code': '075',
#      'grbs_name': 'Министерство науки и высшего образования Российской Федерации',
#      'kbk': '0750704024E452102244'}],
#    'full_price': 55328736.15,
#    'load_id': 299007,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 54314180.03}],
#    'products': [{'name': 'Планшет',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.11.110',
#      'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#      'price': 23880.0,
#      'quantity': 23.0},
#     {'name': 'Интерактивный комплекс тип 2',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.16.160',
#      'okpd2_name': 'Устройства ввода сенсорные',
#      'price': 306221.2,
#      'quantity': 28.0},
#     {'name': 'Шлем виртуальной реальности',
#      'okei_code': '839',
#      'okei_name': 'Комплект',
#      'okpd2_code': '26.20.16.190',
#      'okpd2_name': 'Устройства ввода/вывода данных прочие',
#      'price': 59700.0,
#      'quantity': 23.0},
#     {'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 54924.0,
#      'quantity': 51.0},
#     {'name': 'Операционная система',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 0.0,
#      'quantity': 859.0},
#     {'name': 'Интерактивный комплекс тип 1',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.16.160',
#      'okpd2_name': 'Устройства ввода сенсорные',
#      'price': 290938.0,
#      'quantity': 23.0},
#     {'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
# ...
#      'grbs_code': '903',
#      'grbs_name': None,
#      'kbk': '9030702072E401000244'}],
#    'full_price': 600000.0,
#    'load_id': 310704,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 600000.0}],
#    'products': [{'name': 'Поставка и внедрение программного обеспечения для портала образовательных организаций Республики Алтай obr04. ru',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '58.29.50.000',
#      'okpd2_name': 'Услуги по предоставлению лицензий на право использовать компьютерное программное обеспечение',
#      'price': 600000.0,
#      'quantity': 1.0}],
#    'regnum': '2041110123819000055',
#    'relevant_price': 600000.0,
#    'sign_date': '2019-09-02T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2041110123819000055',
#    'suppliers': [{'supplier_inn': '0277099952',
#      'supplier_kpp': '027401001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИМАЙ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2041110123819000055'},
#   {'budget_code': '12020148',
#    'budget_level_code': '2',
#    'budget_name': 'Республиканский бюджет Республики Тыва',
#    'contract_stage': 'E',
#    'contract_subject': 'Приобретение оборудования (МФУ, ноутбуки, интерактивные доски и т.д.) в рамках реализации федерального проекта "Цифровая образовательная среда" национального проекта "Образование" для нужд Министерства образования и науки Республики Тыва',
#    'currency': 'RUB',
#    'customer_inn': '1701048891',
#    'customer_kpp': '170101001',
#    'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТЫВА',
#    'customer_spz': '03122000118',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 3618561.43,
#      'grbs_code': '923',
#      'grbs_name': None,
#      'kbk': '9230709072E452100242'}],
#    'full_price': 3618561.43,
#    'load_id': 308327,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 3618561.43}],
#    'products': [{'name': 'Интерактивный комплекс, ноутбук учителя, мобильное крепление для интерактивного комплекса, ноутбук мобильного класса, вычислительный блок интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.16.160',
#      'okpd2_name': 'Устройства ввода сенсорные',
#      'price': 3618561.43,
#      'quantity': 1.0}],
#    'regnum': '2170104889119000046',
#    'relevant_price': 3618561.43,
#    'sign_date': '2019-09-02T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2170104889119000046',
#    'suppliers': [{'supplier_inn': '7725808479',
#      'supplier_kpp': '772501001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СКАЙСОФТ ВИКТОРИ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2170104889119000046'},
#   {'budget_code': '30020001',
#    'budget_level_code': '2',
#    'budget_name': 'бюджет Вологодской области',
#    'contract_stage': 'E',
#    'contract_subject': 'Поставка оборудования для внедрения целевой модели цифровой образовательной среды в общеобразовательных организациях в рамках проекта "Цифровая образовательная среда" национального проекта "Образование"',
#    'currency': 'RUB',
#    'customer_inn': '3528011091',
#    'customer_kpp': '352801001',
#    'customer_name': 'БЮДЖЕТНОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОЛОГОДСКОЙ ОБЛАСТИ "ЧЕРЕПОВЕЦКИЙ ХИМИКО-ТЕХНОЛОГИЧЕСКИЙ КОЛЛЕДЖ"',
#    'customer_spz': '03302000176',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 2153451.11,
#      'grbs_code': '006',
#      'grbs_name': None,
#      'kbk': '0060704012E452100244'}],
#    'full_price': 2153460.8,
#    'load_id': 306665,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 2153451.11}],
#    'products': [{'name': 'Многофункциональное устройство (МФУ)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 16857.5,
#      'quantity': 1.0},
#     {'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 52874.3,
#      'quantity': 6.0},
#     {'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 54725.0,
#      'quantity': 2.0},
#     {'name': 'Интерактивный комплекс',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.16.190',
#      'okpd2_name': 'Устройства ввода/вывода данных прочие',
#      'price': 323375.0,
#      'quantity': 2.0},
#     {'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 33153.4,
#      'quantity': 30.0},
#     {'name': 'Вычислительный блок интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.16.190',
#      'okpd2_name': 'Устройства ввода/вывода данных прочие',
#      'price': 34277.75,
#      'quantity': 2.0}],
#    'regnum': '2352801109119000018',
#    'relevant_price': 2153451.11,
#    'sign_date': '2019-08-30T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2352801109119000018',
#    'suppliers': [{'supplier_inn': '7717796090',
#      'supplier_kpp': '771701001',
#      'supplier_name': 'Общество с ограниченной ответственностью «ЭКТИВ СКУЛ»'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2352801109119000018'},
#   {'budget_code': '48020001',
#    'budget_level_code': '2',
#    'budget_name': 'Московская область',
#    'contract_stage': 'E',
#    'contract_subject': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области п. 4.1. «Мероприятие 1. Создание, развитие и эксплуатация (сопровождение и техническая поддержка) ведомственных информационных систем сферы образования» подраздела 12.4 раздела 12 «Перечень мероприятий Подпрограммы 2 «Развитие информационной и технологической инфраструктуры экосистемы цифровой экономики Московской области» государственной программы Московской области «Цифровое Подмосковье» на 2018-2024 годы, утвержденной постановлением Правительства Московской области от 17.10.2017 № 854/38 «Об утверждении государственной программы Московской области «Цифровое Подмосковье» на 2018-2024 годы» (в рамках реализации НП «Образование», РП «Цифровая образовательная среда»)',
#    'currency': 'RUB',
#    'customer_inn': '7706009270',
#    'customer_kpp': '502401001',
#    'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#    'customer_spz': '01482000009',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 6000000.0,
#      'grbs_code': '014',
#      'grbs_name': None,
#      'kbk': '0140410152E400610242'}],
#    'full_price': 6000000.0,
#    'load_id': 310902,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 6000000.0}],
#    'products': [{'name': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': '62.02.30.000',
#      'okpd2_name': 'Услуги по технической поддержке информационных технологий',
#      'price': 633750.0,
#      'quantity': 1.0},
#     {'name': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': '62.02.30.000',
#      'okpd2_name': 'Услуги по технической поддержке информационных технологий',
#      'price': 3287500.0,
#      'quantity': 1.0},
#     {'name': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': '62.02.30.000',
#      'okpd2_name': 'Услуги по технической поддержке информационных технологий',
#      'price': 1117500.0,
#      'quantity': 1.0},
#     {'name': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области',
#      'okei_code': '876',
#      'okei_name': 'Условная единица',
#      'okpd2_code': '62.02.30.000',
#      'okpd2_name': 'Услуги по технической поддержке информационных технологий',
#      'price': 961250.0,
#      'quantity': 1.0}],
#    'regnum': '2770600927019000152',
#    'relevant_price': 6000000.0,
#    'sign_date': '2019-09-02T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2770600927019000152',
#    'suppliers': [{'supplier_inn': '7707049388',
#      'supplier_kpp': '773443001',
#      'supplier_name': 'Публичное акционерное общество «Ростелеком»'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2770600927019000152'},
#   {'budget_code': '94020233',
#    'budget_level_code': '2',
#    'budget_name': 'республиканский бюджет',
#    'contract_stage': 'E',
#    'contract_subject': 'Поставка средств информатизации и автоматизации образовательных процессов',
#    'currency': 'RUB',
#    'customer_inn': '2020001415',
#    'customer_kpp': '201401001',
#    'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#    'customer_spz': '01942000035',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 1209856.88,
#      'grbs_code': '205',
#      'grbs_name': None,
#      'kbk': '2050708029E45210Q244'}],
#    'full_price': 1209856.88,
#    'load_id': 306603,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 1209856.88}],
#    'products': [{'name': 'Мобильное крепление для интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 15828.0,
#      'quantity': 2.0},
#     {'name': 'МФУ (принтер, сканер, копир)',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 16500.44,
#      'quantity': 2.0},
#     {'name': 'Ноутбук мобильного класса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 35200.0,
#      'quantity': 6.0},
#     {'name': 'Интерактивный комплекс',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 237000.0,
#      'quantity': 2.0},
#     {'name': 'Ноутбук учителя',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 60000.0,
#      'quantity': 4.0},
#     {'name': 'Вычислительный блок интерактивного комплекса',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.15.000',
#      'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#      'price': 110000.0,
#      'quantity': 2.0}],
#    'regnum': '2202000141519000132',
#    'relevant_price': 1209856.88,
#    'sign_date': '2019-09-02T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2202000141519000132',
#    'suppliers': [{'supplier_inn': '7731351078',
#      'supplier_kpp': '773101001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2202000141519000132'},
#   {'budget_code': '67020319',
#    'budget_level_code': '2',
#    'budget_name': 'Областной бюджет',
#    'contract_stage': 'E',
#    'contract_subject': 'Поставка цифрового оборудования в рамках федерального проекта «Цифровая образовательная среда» национального проекта «Образование»',
#    'currency': 'RUB',
#    'customer_inn': '7202137498',
#    'customer_kpp': '720301001',
#    'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ТЮМЕНСКОЙ ОБЛАСТИ',
#    'customer_spz': '01672000003',
#    'fp_ids': ['E4'],
#    'fp_info': [{'fp_id': 'E4',
#      'fp_price': 1226995.5,
#      'grbs_code': '013',
#      'grbs_name': None,
#      'kbk': '0130709600E410008242'}],
#    'full_price': 1226995.5,
#    'load_id': 309242,
#    'max_id': 484506,
#    'np_ids': ['E'],
#    'np_info': [{'np_id': 'E', 'np_price': 1226995.5}],
#    'products': [{'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 71094.0,
#      'quantity': 1.0},
#     {'name': 'Ноутбук',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 43877.0,
#      'quantity': 15.0},
#     {'name': 'Интерактивная доска',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': None,
#      'okpd2_name': None,
#      'price': 414199.5,
#      'quantity': 1.0},
#     {'name': 'Вычислительный блок',
#      'okei_code': '796',
#      'okei_name': 'Штука',
#      'okpd2_code': '26.20.30.000',
#      'okpd2_name': 'Устройства автоматической обработки данных прочие',
#      'price': 83547.0,
#      'quantity': 1.0}],
#    'regnum': '2720213749819000033',
#    'relevant_price': 1226995.5,
#    'sign_date': '2019-09-04T00:00:00',
#    'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2720213749819000033',
#    'suppliers': [{'supplier_inn': '7725808479',
#      'supplier_kpp': '772501001',
#      'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СКАЙСОФТ ВИКТОРИ"'}],
#    'year': '2019',
#    'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2720213749819000033'}],
#  'page': 1,
#  'total': 348}

# %%
total = contracts['total']
total
# Out:
# 348

# %%
pages = total//50+1
pages
# Out:
# 7

# %%
for page in range(1,8):
  response = requests.get(f'https://api.spending.gov.ru/v1/natprojects/contracts?fp_id=E4&page={page}')
  print(page)
  print(response)
# Out:
# 1
# <Response [200]>
# 2
# <Response [200]>
# 3
# <Response [200]>
# 4
# <Response [200]>
# 5
# <Response [200]>
# 6
# <Response [200]>
# 7
# <Response [200]>

# %% [markdown]
# **Парсинг**---------------------------------------------------------------

# %%
for key in contracts.keys():
  print(key)
# Out:
# count
# total
# page
# items

# %%
contracts['items']
# Out:
# [{'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 2895911.83,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 2895911.83,
#   'load_id': 236416,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 2895911.83}],
#   'products': [{'name': 'Принтер',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 14850.82,
#     'quantity': 194.0},
#    {'name': 'Принтер',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 14852.75,
#     'quantity': 1.0}],
#   'regnum': '2312331699419000011',
#   'relevant_price': 2895911.83,
#   'sign_date': '2019-02-09T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000011',
#   'suppliers': [{'supplier_inn': '3123314130',
#     'supplier_kpp': '312301001',
#     'supplier_name': 'ООО "РЕСУРС-МЕДИА"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000011'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'ET',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 5261100.0,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 5261100.0,
#   'load_id': 236066,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 5261100.0}],
#   'products': [{'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 26980.0,
#     'quantity': 195.0}],
#   'regnum': '2312331699419000010',
#   'relevant_price': 5261100.0,
#   'sign_date': '2019-02-11T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000010',
#   'suppliers': [{'supplier_inn': '7716870664',
#     'supplier_kpp': '771601001',
#     'supplier_name': 'ООО "ИК ФОРСИС"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000010'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'ET',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 5502535.16,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 5502535.16,
#   'load_id': 236066,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 5502535.16}],
#   'products': [{'name': 'Портативная проекционная система в комплекте с кронштейном и кабелем',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.16.190',
#     'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#     'price': 28218.12,
#     'quantity': 194.0},
#    {'name': 'Портативная проекционная система в комплекте с кронштейном и кабелем',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.16.190',
#     'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#     'price': 28219.88,
#     'quantity': 1.0}],
#   'regnum': '2312331699419000009',
#   'relevant_price': 5502535.16,
#   'sign_date': '2019-02-11T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000009',
#   'suppliers': [{'supplier_inn': '6623127510',
#     'supplier_kpp': '662301001',
#     'supplier_name': 'ООО "Консалтинговая группа Овечкин и партнеры"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000009'},
#  {'budget_code': '90020067',
#   'budget_level_code': '2',
#   'budget_name': 'Окружной бюджет',
#   'contract_stage': 'E',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '8901025527',
#   'customer_kpp': '890101001',
#   'customer_name': 'ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   'customer_spz': '08902000003',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 2800000.0,
#     'grbs_code': '875',
#     'grbs_name': None,
#     'kbk': '8750709023E412440244'}],
#   'full_price': 2800000.0,
#   'load_id': 253965,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 2800000.0}],
#   'products': [{'name': 'Выполнение работ по разработке системы персонифицированного финансирования дополнительного образования в Ямало-Ненецком автономном округе, предусмотренных мероприятием 2.2.4 Выполнение работ по развитию и технической поддержке информационных систем в сфере образования. Государственной программы ЯНАО «Информационное общество на 2014-2021 гг.»',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': '58.29.50.000',
#     'okpd2_name': 'Услуги по предоставлению лицензий на право использовать компьютерное программное обеспечение',
#     'price': 2800000.0,
#     'quantity': 1.0}],
#   'regnum': '2890102552719000007',
#   'relevant_price': 2800000.0,
#   'sign_date': '2019-03-29T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2890102552719000007',
#   'suppliers': [{'supplier_inn': '5018197685',
#     'supplier_kpp': '501801001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНСТИТУТ РАЗВИТИЯ ПЕРСОНИФИЦИРОВАННЫХ СИСТЕМ УПРАВЛЕНИЯ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2890102552719000007'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 591317.0,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 591317.0,
#   'load_id': 257934,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 591317.0}],
#   'products': [{'name': 'Экран для проектора',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.17.150',
#     'okpd2_name': 'Экраны проекционные',
#     'price': 3032.39,
#     'quantity': 194.0},
#    {'name': 'Экран для проектора',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.17.150',
#     'okpd2_name': 'Экраны проекционные',
#     'price': 3033.34,
#     'quantity': 1.0}],
#   'regnum': '2312331699419000007',
#   'relevant_price': 591317.0,
#   'sign_date': '2019-01-21T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000007',
#   'suppliers': [{'supplier_inn': '5404066353',
#     'supplier_kpp': '000000000',
#     'supplier_name': 'Индивидуальный предприниматель Мезенина Аксана Васильевна'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000007'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 10866245.5,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 10866245.5,
#   'load_id': 261505,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 10866245.5}],
#   'products': [{'name': 'Принтер',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 12306.05,
#     'quantity': 882.0},
#    {'name': 'Принтер',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 12309.4,
#     'quantity': 1.0}],
#   'regnum': '2312331699419000014',
#   'relevant_price': 10866245.5,
#   'sign_date': '2019-04-04T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000014',
#   'suppliers': [{'supplier_inn': '3123331167',
#     'supplier_kpp': '312301001',
#     'supplier_name': 'ООО "ЛЛС ГРУПП"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000014'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 23143961.3,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 23143961.3,
#   'load_id': 271949,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 23143961.3}],
#   'products': [{'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 20391.15,
#     'quantity': 1134.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 20397.2,
#     'quantity': 1.0}],
#   'regnum': '2312331699419000020',
#   'relevant_price': 23143961.3,
#   'sign_date': '2019-04-15T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000020',
#   'suppliers': [{'supplier_inn': '3123331167',
#     'supplier_kpp': '312301001',
#     'supplier_name': 'ООО "ЛЛС ГРУПП"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000020'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 1403664.0,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 1403664.0,
#   'load_id': 262582,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 1403664.0}],
#   'products': [{'name': 'экран для проектора',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.17.150',
#     'okpd2_name': 'Экраны проекционные',
#     'price': 2085.68,
#     'quantity': 672.0},
#    {'name': 'экран для проектора',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.17.150',
#     'okpd2_name': 'Экраны проекционные',
#     'price': 2087.04,
#     'quantity': 1.0}],
#   'regnum': '2312331699419000031',
#   'relevant_price': 1403664.0,
#   'sign_date': '2019-04-29T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000031',
#   'suppliers': [{'supplier_inn': '3123445340',
#     'supplier_kpp': '312301001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЕОСТАН"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000031'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 4427215.65,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 4427215.65,
#   'load_id': 265011,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 4427215.65}],
#   'products': [{'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 22703.67,
#     'quantity': 195.0}],
#   'regnum': '2312331699419000036',
#   'relevant_price': 4427215.65,
#   'sign_date': '2019-05-07T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000036',
#   'suppliers': [{'supplier_inn': '3123331167',
#     'supplier_kpp': '312301001',
#     'supplier_name': 'ООО "ЛЛС ГРУПП"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000036'},
#  {'budget_code': '90020067',
#   'budget_level_code': '2',
#   'budget_name': 'Окружной бюджет',
#   'contract_stage': 'E',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '8901025527',
#   'customer_kpp': '890101001',
#   'customer_name': 'ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   'customer_spz': '08902000003',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 3960000.0,
#     'grbs_code': '875',
#     'grbs_name': None,
#     'kbk': '8750709023E412440244'}],
#   'full_price': 3960000.0,
#   'load_id': 270416,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 3960000.0}],
#   'products': [{'name': 'Оказание услуг по технической поддержке действующих в Ямало-Ненецком автономном округе автоматизированных информационных систем в сфере образования',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': '58.29.50.000',
#     'okpd2_name': 'Услуги по предоставлению лицензий на право использовать компьютерное программное обеспечение',
#     'price': 3960000.0,
#     'quantity': 1.0}],
#   'regnum': '2890102552719000012',
#   'relevant_price': 3960000.0,
#   'sign_date': '2019-05-20T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2890102552719000012',
#   'suppliers': [{'supplier_inn': '6311093270',
#     'supplier_kpp': '631101001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИРСОФТ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2890102552719000012'},
#  {'budget_code': '69020002',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Челябинской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '7447041828',
#   'customer_kpp': '745301001',
#   'customer_name': 'ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "ЧЕЛЯБИНСКИЙ ИНСТИТУТ ПЕРЕПОДГОТОВКИ И ПОВЫШЕНИЯ КВАЛИФИКАЦИИ РАБОТНИКОВ ОБРАЗОВАНИЯ"',
#   'customer_spz': '03692000088',
#   'fp_ids': ['E2', 'E4'],
#   'fp_info': [{'fp_id': 'E2',
#     'fp_price': 10746.0,
#     'grbs_code': '012',
#     'grbs_name': None,
#     'kbk': '0120705030E203180244'},
#    {'fp_id': 'E4',
#     'fp_price': 3223.8,
#     'grbs_code': '012',
#     'grbs_name': None,
#     'kbk': '0120705030E403190244'}],
#   'full_price': 53732.14,
#   'load_id': 274565,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 13969.8}],
#   'products': [{'name': 'Бумага для офисной техники',
#     'okei_code': '778',
#     'okei_name': 'Упаковка',
#     'okpd2_code': '17.12.14.119',
#     'okpd2_name': 'Бумага для печати прочая',
#     'price': 214.92,
#     'quantity': 249.0},
#    {'name': 'Бумага для офисной техники',
#     'okei_code': '778',
#     'okei_name': 'Упаковка',
#     'okpd2_code': '17.12.14.119',
#     'okpd2_name': 'Бумага для печати прочая',
#     'price': 217.06,
#     'quantity': 1.0}],
#   'regnum': '2744704182819000798',
#   'relevant_price': 13969.8,
#   'sign_date': '2019-06-03T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2744704182819000798',
#   'suppliers': [{'supplier_inn': '7448122237',
#     'supplier_kpp': '744801001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕДЕНТ Ч"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2744704182819000798'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 27923448.0,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 27923448.0,
#   'load_id': 275420,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 27923448.0}],
#   'products': [{'name': 'Портативная проекционная система в комплекте с кронштейном и кабелем',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.16.190',
#     'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#     'price': 32774.0,
#     'quantity': 852.0}],
#   'regnum': '2312331699419000042',
#   'relevant_price': 27923448.0,
#   'sign_date': '2019-06-07T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000042',
#   'suppliers': [{'supplier_inn': '7727845469',
#     'supplier_kpp': '772701001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЕТРА"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000042'},
#  {'budget_code': '99010001',
#   'budget_level_code': '1',
#   'budget_name': 'Федеральный бюджет',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '0711033902',
#   'customer_kpp': '072501001',
#   'customer_name': 'МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ, НАУКИ И ПО ДЕЛАМ МОЛОДЕЖИ КАБАРДИНО-БАЛКАРСКОЙ РЕСПУБЛИКИ',
#   'customer_spz': '01042000007',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 3256200.0,
#     'grbs_code': '973',
#     'grbs_name': None,
#     'kbk': '9730709022E452100244'}],
#   'full_price': 3256200.0,
#   'load_id': 278797,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 3256200.0}],
#   'products': [{'name': 'поставка учебного оборудования (Конструктор для практико-ориентированного изучения устройства и принципов работы механических моделей)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '32.99.53.130',
#     'okpd2_name': 'Приборы, аппаратура и устройства учебные демонстрационные',
#     'price': 40200.0,
#     'quantity': 81.0}],
#   'regnum': '2071103390219000011',
#   'relevant_price': 3256200.0,
#   'sign_date': '2019-06-06T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2071103390219000011',
#   'suppliers': [{'supplier_inn': '0909009071',
#     'supplier_kpp': '090901001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СЕЛЕНА"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2071103390219000011'},
#  {'budget_code': '26020001',
#   'budget_level_code': '2',
#   'budget_name': 'Бюджет Белгородской области',
#   'contract_stage': 'EC',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '3123316994',
#   'customer_kpp': '312301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   'customer_spz': '01262000034',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 5065800.18,
#     'grbs_code': '810',
#     'grbs_name': None,
#     'kbk': '8100702022E4E0000242'}],
#   'full_price': 5065800.18,
#   'load_id': 281319,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 5065800.18}],
#   'products': [{'name': 'Портативные проекционные системы в комплекте с кронштейном и кабелем для нужд общеобразовательных организаций Белгородской области',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.16.190',
#     'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#     'price': 25978.46,
#     'quantity': 194.0},
#    {'name': 'Портативные проекционные системы в комплекте с кронштейном и кабелем для нужд общеобразовательных организаций Белгородской области',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.70.16.190',
#     'okpd2_name': 'Проекторы изображений прочие, не включенные в другие группировки',
#     'price': 25978.94,
#     'quantity': 1.0}],
#   'regnum': '2312331699419000044',
#   'relevant_price': 5065800.18,
#   'sign_date': '2019-06-24T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2312331699419000044',
#   'suppliers': [{'supplier_inn': '7718825353',
#     'supplier_kpp': '771801001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕНТА"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2312331699419000044'},
#  {'budget_code': '39020004',
#   'budget_level_code': '2',
#   'budget_name': 'областной бюджет',
#   'contract_stage': 'ET',
#   'contract_subject': None,
#   'currency': 'RUB',
#   'customer_inn': '4205123000',
#   'customer_kpp': '420501001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ КЕМЕРОВСКОЙ ОБЛАСТИ',
#   'customer_spz': '01392000019',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 104174784.0,
#     'grbs_code': '012',
#     'grbs_name': None,
#     'kbk': '0120709101E452100242'}],
#   'full_price': 104174784.0,
#   'load_id': 282750,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 104174784.0}],
#   'products': [{'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 52992.0,
#     'quantity': 98.0},
#    {'name': 'Ноутбук мобильного класса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 34080.0,
#     'quantity': 1470.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 50784.0,
#     'quantity': 294.0},
#    {'name': 'Доставка и монтаж',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': '33.20.29.000',
#     'okpd2_name': 'Услуги по монтажу прочего оборудования общего назначения, не включенного в другие группировки',
#     'price': 5760.0,
#     'quantity': 49.0},
#    {'name': 'Вычислительный блок интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.40.110',
#     'okpd2_name': 'Устройства и блоки питания вычислительных машин',
#     'price': 33072.0,
#     'quantity': 98.0},
#    {'name': 'МФУ',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.18.000',
#     'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#     'price': 16224.0,
#     'quantity': 49.0},
#    {'name': 'Интерактивный комплекс',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.160',
#     'okpd2_name': 'Устройства ввода сенсорные',
#     'price': 302400.0,
#     'quantity': 98.0}],
#   'regnum': '2420512300019000055',
#   'relevant_price': 104174784.0,
#   'sign_date': '2019-06-27T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2420512300019000055',
#   'suppliers': [{'supplier_inn': '7707049388',
#     'supplier_kpp': '420543001',
#     'supplier_name': 'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РОСТЕЛЕКОМ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2420512300019000055'},
#  {'budget_code': '67020319',
#   'budget_level_code': '2',
#   'budget_name': 'Областной бюджет',
#   'contract_stage': 'E',
#   'contract_subject': 'Оказание услуг по доступу к информационно-коммуникационной сети Интернет',
#   'currency': 'RUB',
#   'customer_inn': '7202190205',
#   'customer_kpp': '720301001',
#   'customer_name': 'ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ТЮМЕНСКОЙ ОБЛАСТИ "ЦЕНТР ИНФОРМАЦИОННЫХ ТЕХНОЛОГИЙ ТЮМЕНСКОЙ ОБЛАСТИ"',
#   'customer_spz': '03672000068',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 102336.0,
#     'grbs_code': '159',
#     'grbs_name': None,
#     'kbk': '1590410530E415520242'}],
#   'full_price': 289952.0,
#   'load_id': 317225,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 102336.0}],
#   'products': [{'name': 'Услуги по доступу к информационно-коммуникационной сети Интернет',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 7072.0,
#     'quantity': 41.0}],
#   'regnum': '2720219020519000015',
#   'relevant_price': 102336.0,
#   'sign_date': '2019-04-02T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2720219020519000015',
#   'suppliers': [{'supplier_inn': '7707049388',
#     'supplier_kpp': '668543001',
#     'supplier_name': 'Публичное акционерное общество "Ростелеком"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2720219020519000015'},
#  {'budget_code': '09020936',
#   'budget_level_code': '2',
#   'budget_name': 'Республиканский бюджет Республики Мордовия',
#   'contract_stage': 'EC',
#   'contract_subject': 'поставка компьютерного и интерактивного оборудования',
#   'currency': 'RUB',
#   'customer_inn': '1326047197',
#   'customer_kpp': '132601001',
#   'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ РЕСПУБЛИКИ МОРДОВИЯ',
#   'customer_spz': '01092000013',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 18063880.0,
#     'grbs_code': '809',
#     'grbs_name': None,
#     'kbk': '8090709022E452100244'}],
#   'full_price': 18063880.0,
#   'load_id': 298943,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 18063880.0}],
#   'products': [{'name': 'МФУ (принтер, сканер, копир)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.18.000',
#     'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#     'price': 17485.0,
#     'quantity': 8.0},
#    {'name': 'Ноутбук для управленческого персонала',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 65250.0,
#     'quantity': 48.0},
#    {'name': 'Ноутбук учителя',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 76500.0,
#     'quantity': 16.0},
#    {'name': 'Ноутбук мобильного класса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 35500.0,
#     'quantity': 240.0},
#    {'name': 'Интерактивный комплекс',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.160',
#     'okpd2_name': 'Устройства ввода сенсорные',
#     'price': 315500.0,
#     'quantity': 16.0}],
#   'regnum': '2132604719719000008',
#   'relevant_price': 18063880.0,
#   'sign_date': '2019-07-03T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2132604719719000008',
#   'suppliers': [{'supplier_inn': '1326251273',
#     'supplier_kpp': '132601001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СМАРТ ГРУПП"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2132604719719000008'},
#  {'budget_code': '67020319',
#   'budget_level_code': '2',
#   'budget_name': 'Областной бюджет',
#   'contract_stage': 'EC',
#   'contract_subject': 'Поставка комплектов оборудования для внедрения целевой модели цифровой образовательной среды',
#   'currency': 'RUB',
#   'customer_inn': '7202137498',
#   'customer_kpp': '720301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ТЮМЕНСКОЙ ОБЛАСТИ',
#   'customer_spz': '01672000003',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 84736666.5,
#     'grbs_code': '013',
#     'grbs_name': None,
#     'kbk': '0130709600E410008242'}],
#   'full_price': 84736666.5,
#   'load_id': 299179,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 84736666.5}],
#   'products': [{'name': 'Комплект оборудования для внедрения целевой модели \nцифровой образовательной среды',
#     'okei_code': '839',
#     'okei_name': 'Комплект',
#     'okpd2_code': '32.99.53.130',
#     'okpd2_name': 'Приборы, аппаратура и устройства учебные демонстрационные',
#     'price': 2824555.55,
#     'quantity': 30.0}],
#   'regnum': '2720213749819000019',
#   'relevant_price': 84736666.5,
#   'sign_date': '2019-07-03T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2720213749819000019',
#   'suppliers': [{'supplier_inn': '7728734000',
#     'supplier_kpp': '772501001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТЛАЙН ПРОЕКТЫ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2720213749819000019'},
#  {'budget_code': '90020067',
#   'budget_level_code': '2',
#   'budget_name': 'Окружной бюджет',
#   'contract_stage': 'E',
#   'contract_subject': 'Выполнение работ по доработке региональной информационной системы управления сферой образования Ямало-Ненецкого автономного округа по расчету показателей доступности дошкольного образования',
#   'currency': 'RUB',
#   'customer_inn': '8901025527',
#   'customer_kpp': '890101001',
#   'customer_name': 'ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   'customer_spz': '08902000003',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 3500000.0,
#     'grbs_code': '875',
#     'grbs_name': None,
#     'kbk': '8750709023E412440244'}],
#   'full_price': 3500000.0,
#   'load_id': 299215,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 3500000.0}],
#   'products': [{'name': 'Выполнение работ по доработке региональной информационной системы управления сферой образования Ямало-Ненецкого автономного округа по расчету показателей доступности дошкольного образования',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': '58.29.50.000',
#     'okpd2_name': 'Услуги по предоставлению лицензий на право использовать компьютерное программное обеспечение',
#     'price': 3500000.0,
#     'quantity': 1.0}],
#   'regnum': '2890102552719000021',
#   'relevant_price': 3500000.0,
#   'sign_date': '2019-07-10T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2890102552719000021',
#   'suppliers': [{'supplier_inn': '6311102655',
#     'supplier_kpp': '631101001',
#     'supplier_name': 'АКЦИОНЕРНОЕ ОБЩЕСТВО "ИРТЕХ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2890102552719000021'},
#  {'budget_code': '10020001',
#   'budget_level_code': '2',
#   'budget_name': 'Республиканский бюджет Республики Северная Осетия-Алания',
#   'contract_stage': 'EC',
#   'contract_subject': 'Поставка оборудования для внедрения целевой модели цифровой среды в общеобразовательных организациях и профессиональных образовательных организациях',
#   'currency': 'RUB',
#   'customer_inn': '1515906542',
#   'customer_kpp': '151301001',
#   'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ СЕВЕРНАЯ ОСЕТИЯ-АЛАНИЯ',
#   'customer_spz': '03102000007',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 20147950.2,
#     'grbs_code': '738',
#     'grbs_name': None,
#     'kbk': '738070209ИE452100242'}],
#   'full_price': 20147950.2,
#   'load_id': 314219,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 20147950.2}],
#   'products': [{'name': 'МФУ (принтер, сканер, копир)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.18.000',
#     'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#     'price': 19099.0,
#     'quantity': 20.0},
#    {'name': 'Ноутбук мобильного класса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 24881.05,
#     'quantity': 300.0},
#    {'name': 'Мобильное крепление для интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.40.190',
#     'okpd2_name': 'Комплектующие и запасные части для вычислительных машин прочие, не включенные в другие группировки',
#     'price': 13200.0,
#     'quantity': 20.0},
#    {'name': 'Ноутбук учителя',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 58797.76,
#     'quantity': 30.0},
#    {'name': 'Интерактивный комплекс',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.160',
#     'okpd2_name': 'Устройства ввода сенсорные',
#     'price': 277200.0,
#     'quantity': 20.0},
#    {'name': 'Вычислительный блок интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 46200.0,
#     'quantity': 20.0},
#    {'name': 'Ноутбук для управленческого персонала',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 47571.53,
#     'quantity': 80.0}],
#   'regnum': '2151590654219000015',
#   'relevant_price': 20147950.2,
#   'sign_date': '2019-07-09T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2151590654219000015',
#   'suppliers': [{'supplier_inn': '3257003993',
#     'supplier_kpp': '773001001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНТ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2151590654219000015'},
#  {'budget_code': '99010001',
#   'budget_level_code': '1',
#   'budget_name': 'Федеральный бюджет',
#   'contract_stage': 'EC',
#   'contract_subject': 'поставка компьютерной техники',
#   'currency': 'RUB',
#   'customer_inn': '0711033902',
#   'customer_kpp': '072501001',
#   'customer_name': 'МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ, НАУКИ И ПО ДЕЛАМ МОЛОДЕЖИ КАБАРДИНО-БАЛКАРСКОЙ РЕСПУБЛИКИ',
#   'customer_spz': '01042000007',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 34580809.9,
#     'grbs_code': '973',
#     'grbs_name': None,
#     'kbk': '9730709022E452100242'}],
#   'full_price': 34580809.9,
#   'load_id': 298919,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 34580809.9}],
#   'products': [{'name': 'МФУ',
#     'okei_code': '839',
#     'okei_name': 'Комплект',
#     'okpd2_code': '26.20.18.000',
#     'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#     'price': 35649.42,
#     'quantity': 15.0},
#    {'name': 'ноутбук (учителя)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 39622.4,
#     'quantity': 32.0},
#    {'name': 'интерактивный комплекс',
#     'okei_code': '839',
#     'okei_name': 'Комплект',
#     'okpd2_code': '26.20.16.190',
#     'okpd2_name': 'Устройства ввода/вывода данных прочие',
#     'price': 209250.0,
#     'quantity': 32.0},
#    {'name': 'ноутбук (для управленческого персонала)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 39622.4,
#     'quantity': 96.0},
#    {'name': 'вычислительный блок интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.13.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые, содержащие в одном корпусе центральный процессор и устройство ввода и вывода, объединенные или нет для автоматической обработки данных',
#     'price': 77500.0,
#     'quantity': 32.0},
#    {'name': 'ноутбук (мобильного класса)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 39622.4,
#     'quantity': 480.0},
#    {'name': 'мобильное крепление для интерактивного комплекса',
#     'okei_code': '839',
#     'okei_name': 'Комплект',
#     'okpd2_code': '26.20.40.190',
#     'okpd2_name': 'Комплектующие и запасные части для вычислительных машин прочие, не включенные в другие группировки',
#     'price': 23250.0,
#     'quantity': 32.0},
#    {'name': 'МФУ',
#     'okei_code': '839',
#     'okei_name': 'Комплект',
#     'okpd2_code': '26.20.18.000',
#     'okpd2_name': 'Устройства периферийные с двумя или более функциями: печать данных, копирование, сканирование, прием и передача факсимильных сообщений',
#     'price': 35649.4,
#     'quantity': 1.0}],
#   'regnum': '2071103390219000021',
#   'relevant_price': 34580809.9,
#   'sign_date': '2019-07-17T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2071103390219000021',
#   'suppliers': [{'supplier_inn': '0700000310',
#     'supplier_kpp': '072501001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КАББАЛКМЕСТПРОМ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2071103390219000021'},
#  {'budget_code': '94020233',
#   'budget_level_code': '2',
#   'budget_name': 'республиканский бюджет',
#   'contract_stage': 'E',
#   'contract_subject': 'Поставка средств информатизации и автоматизации образовательных процессов',
#   'currency': 'RUB',
#   'customer_inn': '2020001415',
#   'customer_kpp': '201401001',
#   'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#   'customer_spz': '01942000035',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 205983963.44,
#     'grbs_code': '205',
#     'grbs_name': None,
#     'kbk': '2050709029E45210Q244'}],
#   'full_price': 205983963.44,
#   'load_id': 298971,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 205983963.44}],
#   'products': [{'name': 'Ноутбук учителя',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 60637.0,
#     'quantity': 188.0},
#    {'name': 'МФУ (принтер, сканер, копир)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 16172.0,
#     'quantity': 94.0},
#    {'name': 'Ноутбук мобильного класса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 34644.0,
#     'quantity': 2820.0},
#    {'name': 'Мобильное крепление для интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 15342.51,
#     'quantity': 188.0},
#    {'name': 'Вычислительный блок интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 106222.87,
#     'quantity': 188.0},
#    {'name': 'Ноутбук для управленческого персонала',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 51337.0,
#     'quantity': 564.0},
#    {'name': 'Интерактивный комплекс',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 231700.0,
#     'quantity': 188.0}],
#   'regnum': '2202000141519000087',
#   'relevant_price': 205983963.44,
#   'sign_date': '2019-07-22T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2202000141519000087',
#   'suppliers': [{'supplier_inn': '7731351078',
#     'supplier_kpp': '773101001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2202000141519000087'},
#  {'budget_code': '24020001',
#   'budget_level_code': '2',
#   'budget_name': 'Областной бюджет',
#   'contract_stage': 'E',
#   'contract_subject': 'Комплект компьютерного и интерактивного оборудования',
#   'currency': 'RUB',
#   'customer_inn': '2901185216',
#   'customer_kpp': '290101001',
#   'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АРХАНГЕЛЬСКОЙ ОБЛАСТИ',
#   'customer_spz': '01242000015',
#   'fp_ids': ['E1', 'E4'],
#   'fp_info': [{'fp_id': 'E1',
#     'fp_price': 25379236.15,
#     'grbs_code': '075',
#     'grbs_name': 'Министерство науки и высшего образования Российской Федерации',
#     'kbk': '0750702021E151690244'},
#    {'fp_id': 'E4',
#     'fp_price': 28934943.88,
#     'grbs_code': '075',
#     'grbs_name': 'Министерство науки и высшего образования Российской Федерации',
#     'kbk': '0750704024E452102244'}],
#   'full_price': 55328736.15,
#   'load_id': 299007,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 54314180.03}],
#   'products': [{'name': 'Планшет',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.11.110',
#     'okpd2_name': 'Компьютеры портативные массой не более 10 кг, такие как ноутбуки, планшетные компьютеры, карманные компьютеры, в том числе совмещающие функции мобильного телефонного аппарата',
#     'price': 23880.0,
#     'quantity': 23.0},
#    {'name': 'Интерактивный комплекс тип 2',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.160',
#     'okpd2_name': 'Устройства ввода сенсорные',
#     'price': 306221.2,
#     'quantity': 28.0},
#    {'name': 'Шлем виртуальной реальности',
#     'okei_code': '839',
#     'okei_name': 'Комплект',
#     'okpd2_code': '26.20.16.190',
#     'okpd2_name': 'Устройства ввода/вывода данных прочие',
#     'price': 59700.0,
#     'quantity': 23.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 54924.0,
#     'quantity': 51.0},
#    {'name': 'Операционная система',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 0.0,
#     'quantity': 859.0},
#    {'name': 'Интерактивный комплекс тип 1',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.160',
#     'okpd2_name': 'Устройства ввода сенсорные',
#     'price': 290938.0,
#     'quantity': 23.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 53630.5,
#     'quantity': 84.0},
#    {'name': 'Вычислительный блок интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.14.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые, поставляемые в виде систем для автоматической обработки данных',
#     'price': 51431.55,
#     'quantity': 51.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 32516.6,
#     'quantity': 650.0},
#    {'name': 'Карта памяти для фотоаппарата/видеокамеры',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.22.000',
#     'okpd2_name': 'Устройства запоминающие полупроводниковые, сохраняющие информацию при выключении питания',
#     'price': 1492.5,
#     'quantity': 46.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 148255.0,
#     'quantity': 23.0},
#    {'name': 'Зд оборудование (3д принтер)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.120',
# ...
#   'currency': 'RUB',
#   'customer_inn': '0411101238',
#   'customer_kpp': '041101001',
#   'customer_name': 'БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ РЕСПУБЛИКИ АЛТАЙ "РЕСПУБЛИКАНСКИЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   'customer_spz': '03772000111',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 600000.0,
#     'grbs_code': '903',
#     'grbs_name': None,
#     'kbk': '9030702072E401000244'}],
#   'full_price': 600000.0,
#   'load_id': 310704,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 600000.0}],
#   'products': [{'name': 'Поставка и внедрение программного обеспечения для портала образовательных организаций Республики Алтай obr04. ru',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '58.29.50.000',
#     'okpd2_name': 'Услуги по предоставлению лицензий на право использовать компьютерное программное обеспечение',
#     'price': 600000.0,
#     'quantity': 1.0}],
#   'regnum': '2041110123819000055',
#   'relevant_price': 600000.0,
#   'sign_date': '2019-09-02T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2041110123819000055',
#   'suppliers': [{'supplier_inn': '0277099952',
#     'supplier_kpp': '027401001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИМАЙ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2041110123819000055'},
#  {'budget_code': '12020148',
#   'budget_level_code': '2',
#   'budget_name': 'Республиканский бюджет Республики Тыва',
#   'contract_stage': 'E',
#   'contract_subject': 'Приобретение оборудования (МФУ, ноутбуки, интерактивные доски и т.д.) в рамках реализации федерального проекта "Цифровая образовательная среда" национального проекта "Образование" для нужд Министерства образования и науки Республики Тыва',
#   'currency': 'RUB',
#   'customer_inn': '1701048891',
#   'customer_kpp': '170101001',
#   'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТЫВА',
#   'customer_spz': '03122000118',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 3618561.43,
#     'grbs_code': '923',
#     'grbs_name': None,
#     'kbk': '9230709072E452100242'}],
#   'full_price': 3618561.43,
#   'load_id': 308327,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 3618561.43}],
#   'products': [{'name': 'Интерактивный комплекс, ноутбук учителя, мобильное крепление для интерактивного комплекса, ноутбук мобильного класса, вычислительный блок интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.160',
#     'okpd2_name': 'Устройства ввода сенсорные',
#     'price': 3618561.43,
#     'quantity': 1.0}],
#   'regnum': '2170104889119000046',
#   'relevant_price': 3618561.43,
#   'sign_date': '2019-09-02T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2170104889119000046',
#   'suppliers': [{'supplier_inn': '7725808479',
#     'supplier_kpp': '772501001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СКАЙСОФТ ВИКТОРИ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2170104889119000046'},
#  {'budget_code': '30020001',
#   'budget_level_code': '2',
#   'budget_name': 'бюджет Вологодской области',
#   'contract_stage': 'E',
#   'contract_subject': 'Поставка оборудования для внедрения целевой модели цифровой образовательной среды в общеобразовательных организациях в рамках проекта "Цифровая образовательная среда" национального проекта "Образование"',
#   'currency': 'RUB',
#   'customer_inn': '3528011091',
#   'customer_kpp': '352801001',
#   'customer_name': 'БЮДЖЕТНОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОЛОГОДСКОЙ ОБЛАСТИ "ЧЕРЕПОВЕЦКИЙ ХИМИКО-ТЕХНОЛОГИЧЕСКИЙ КОЛЛЕДЖ"',
#   'customer_spz': '03302000176',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 2153451.11,
#     'grbs_code': '006',
#     'grbs_name': None,
#     'kbk': '0060704012E452100244'}],
#   'full_price': 2153460.8,
#   'load_id': 306665,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 2153451.11}],
#   'products': [{'name': 'Многофункциональное устройство (МФУ)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 16857.5,
#     'quantity': 1.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 52874.3,
#     'quantity': 6.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 54725.0,
#     'quantity': 2.0},
#    {'name': 'Интерактивный комплекс',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.190',
#     'okpd2_name': 'Устройства ввода/вывода данных прочие',
#     'price': 323375.0,
#     'quantity': 2.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 33153.4,
#     'quantity': 30.0},
#    {'name': 'Вычислительный блок интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.16.190',
#     'okpd2_name': 'Устройства ввода/вывода данных прочие',
#     'price': 34277.75,
#     'quantity': 2.0}],
#   'regnum': '2352801109119000018',
#   'relevant_price': 2153451.11,
#   'sign_date': '2019-08-30T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2352801109119000018',
#   'suppliers': [{'supplier_inn': '7717796090',
#     'supplier_kpp': '771701001',
#     'supplier_name': 'Общество с ограниченной ответственностью «ЭКТИВ СКУЛ»'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2352801109119000018'},
#  {'budget_code': '48020001',
#   'budget_level_code': '2',
#   'budget_name': 'Московская область',
#   'contract_stage': 'E',
#   'contract_subject': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области п. 4.1. «Мероприятие 1. Создание, развитие и эксплуатация (сопровождение и техническая поддержка) ведомственных информационных систем сферы образования» подраздела 12.4 раздела 12 «Перечень мероприятий Подпрограммы 2 «Развитие информационной и технологической инфраструктуры экосистемы цифровой экономики Московской области» государственной программы Московской области «Цифровое Подмосковье» на 2018-2024 годы, утвержденной постановлением Правительства Московской области от 17.10.2017 № 854/38 «Об утверждении государственной программы Московской области «Цифровое Подмосковье» на 2018-2024 годы» (в рамках реализации НП «Образование», РП «Цифровая образовательная среда»)',
#   'currency': 'RUB',
#   'customer_inn': '7706009270',
#   'customer_kpp': '502401001',
#   'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   'customer_spz': '01482000009',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 6000000.0,
#     'grbs_code': '014',
#     'grbs_name': None,
#     'kbk': '0140410152E400610242'}],
#   'full_price': 6000000.0,
#   'load_id': 310902,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 6000000.0}],
#   'products': [{'name': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': '62.02.30.000',
#     'okpd2_name': 'Услуги по технической поддержке информационных технологий',
#     'price': 633750.0,
#     'quantity': 1.0},
#    {'name': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': '62.02.30.000',
#     'okpd2_name': 'Услуги по технической поддержке информационных технологий',
#     'price': 3287500.0,
#     'quantity': 1.0},
#    {'name': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': '62.02.30.000',
#     'okpd2_name': 'Услуги по технической поддержке информационных технологий',
#     'price': 1117500.0,
#     'quantity': 1.0},
#    {'name': 'Выполнение работ в 2019 году по техническому сопровождению и развитию специального программного обеспечения единой информационной системы мониторинга и анализа контингента обучающихся в общеобразовательных организациях, организациях начального и среднего профессионального, высшего профессионального образования в Московской области',
#     'okei_code': '876',
#     'okei_name': 'Условная единица',
#     'okpd2_code': '62.02.30.000',
#     'okpd2_name': 'Услуги по технической поддержке информационных технологий',
#     'price': 961250.0,
#     'quantity': 1.0}],
#   'regnum': '2770600927019000152',
#   'relevant_price': 6000000.0,
#   'sign_date': '2019-09-02T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2770600927019000152',
#   'suppliers': [{'supplier_inn': '7707049388',
#     'supplier_kpp': '773443001',
#     'supplier_name': 'Публичное акционерное общество «Ростелеком»'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2770600927019000152'},
#  {'budget_code': '94020233',
#   'budget_level_code': '2',
#   'budget_name': 'республиканский бюджет',
#   'contract_stage': 'E',
#   'contract_subject': 'Поставка средств информатизации и автоматизации образовательных процессов',
#   'currency': 'RUB',
#   'customer_inn': '2020001415',
#   'customer_kpp': '201401001',
#   'customer_name': 'МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#   'customer_spz': '01942000035',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 1209856.88,
#     'grbs_code': '205',
#     'grbs_name': None,
#     'kbk': '2050708029E45210Q244'}],
#   'full_price': 1209856.88,
#   'load_id': 306603,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 1209856.88}],
#   'products': [{'name': 'Мобильное крепление для интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 15828.0,
#     'quantity': 2.0},
#    {'name': 'МФУ (принтер, сканер, копир)',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 16500.44,
#     'quantity': 2.0},
#    {'name': 'Ноутбук мобильного класса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 35200.0,
#     'quantity': 6.0},
#    {'name': 'Интерактивный комплекс',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 237000.0,
#     'quantity': 2.0},
#    {'name': 'Ноутбук учителя',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 60000.0,
#     'quantity': 4.0},
#    {'name': 'Вычислительный блок интерактивного комплекса',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.15.000',
#     'okpd2_name': 'Машины вычислительные электронные цифровые прочие, содержащие или не содержащие в одном корпусе одно или два из следующих устройств для автоматической обработки данных: запоминающие устройства, устройства ввода, устройства вывода',
#     'price': 110000.0,
#     'quantity': 2.0}],
#   'regnum': '2202000141519000132',
#   'relevant_price': 1209856.88,
#   'sign_date': '2019-09-02T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2202000141519000132',
#   'suppliers': [{'supplier_inn': '7731351078',
#     'supplier_kpp': '773101001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2202000141519000132'},
#  {'budget_code': '67020319',
#   'budget_level_code': '2',
#   'budget_name': 'Областной бюджет',
#   'contract_stage': 'E',
#   'contract_subject': 'Поставка цифрового оборудования в рамках федерального проекта «Цифровая образовательная среда» национального проекта «Образование»',
#   'currency': 'RUB',
#   'customer_inn': '7202137498',
#   'customer_kpp': '720301001',
#   'customer_name': 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ТЮМЕНСКОЙ ОБЛАСТИ',
#   'customer_spz': '01672000003',
#   'fp_ids': ['E4'],
#   'fp_info': [{'fp_id': 'E4',
#     'fp_price': 1226995.5,
#     'grbs_code': '013',
#     'grbs_name': None,
#     'kbk': '0130709600E410008242'}],
#   'full_price': 1226995.5,
#   'load_id': 309242,
#   'max_id': 484506,
#   'np_ids': ['E'],
#   'np_info': [{'np_id': 'E', 'np_price': 1226995.5}],
#   'products': [{'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 71094.0,
#     'quantity': 1.0},
#    {'name': 'Ноутбук',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 43877.0,
#     'quantity': 15.0},
#    {'name': 'Интерактивная доска',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': None,
#     'okpd2_name': None,
#     'price': 414199.5,
#     'quantity': 1.0},
#    {'name': 'Вычислительный блок',
#     'okei_code': '796',
#     'okei_name': 'Штука',
#     'okpd2_code': '26.20.30.000',
#     'okpd2_name': 'Устройства автоматической обработки данных прочие',
#     'price': 83547.0,
#     'quantity': 1.0}],
#   'regnum': '2720213749819000033',
#   'relevant_price': 1226995.5,
#   'sign_date': '2019-09-04T00:00:00',
#   'spending_url': 'https://spending.gov.ru/goscontracts/contracts/2720213749819000033',
#   'suppliers': [{'supplier_inn': '7725808479',
#     'supplier_kpp': '772501001',
#     'supplier_name': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СКАЙСОФТ ВИКТОРИ"'}],
#   'year': '2019',
#   'zakupki_url': 'http://zakupki.gov.ru/epz/contract/contractCard/common-info.html?reestrNumber=2720213749819000033'}]

# %%
contracts['items'][0]['fp_info']
# Out:
# [{'fp_id': 'E4',
#   'fp_price': 2895911.83,
#   'grbs_code': '810',
#   'grbs_name': None,
#   'kbk': '8100702022E4E0000242'}]

# %%
listtt=contracts['items'][0]['fp_info']
a={}
a=listtt[0]
a
# Out:
# {'fp_id': 'E4',
#  'fp_price': 2895911.83,
#  'grbs_code': '810',
#  'grbs_name': None,
#  'kbk': '8100702022E4E0000242'}

# %%
listtt=contracts['items'][0]['fp_info']
a={}
a=listtt[0]
a['fp_price']
# Out:
# 2895911.83

# %%
contracts['items'][0]['suppliers']
# Out:
# [{'supplier_inn': '3123314130',
#   'supplier_kpp': '312301001',
#   'supplier_name': 'ООО "РЕСУРС-МЕДИА"'}]

# %%
contracts['items'][0]['customer_name']
# Out:
# 'ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ'

# %%
contracts_tab = [] #в этот список будем складывать информацию о каждом контракте
for page in range(1, 8):
  response = requests.get(f'https://api.spending.gov.ru/v1/natprojects/contracts?fp_id=E4&page={page}')
  print(page)
  print(response)
  contracts = response.json()
  lst = contracts['items']
  for cnt in lst:
    for prod in cnt['fp_info']:
      list1=cnt['fp_info']
      a={}
      a=list1[0]
      one_cont = []
      one_cont.append(cnt['customer_name'])
      #one_cont.append(cnt['customer_inn'])
      #one_cont.append(cnt['customer_kpp'])
      one_cont.append(a['fp_price'])
      list2=cnt['suppliers']
      b={}
      b=list2[0]
      one_cont.append(b['supplier_name'])
      one_cont.append(cnt['year'])
      contracts_tab.append(one_cont)
# Out:
# 1
# <Response [200]>
# 2
# <Response [200]>
# 3
# <Response [200]>
# 4
# <Response [200]>
# 5
# <Response [200]>
# 6
# <Response [200]>
# 7
# <Response [200]>

# %%
contracts_tab
# Out:
# [['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   2895911.83,
#   'ООО "РЕСУРС-МЕДИА"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   5261100.0,
#   'ООО "ИК ФОРСИС"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   5502535.16,
#   'ООО "Консалтинговая группа Овечкин и партнеры"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   2800000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНСТИТУТ РАЗВИТИЯ ПЕРСОНИФИЦИРОВАННЫХ СИСТЕМ УПРАВЛЕНИЯ"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   591317.0,
#   'Индивидуальный предприниматель Мезенина Аксана Васильевна',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   10866245.5,
#   'ООО "ЛЛС ГРУПП"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   23143961.3,
#   'ООО "ЛЛС ГРУПП"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   1403664.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЕОСТАН"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   4427215.65,
#   'ООО "ЛЛС ГРУПП"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   3960000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИРСОФТ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "ЧЕЛЯБИНСКИЙ ИНСТИТУТ ПЕРЕПОДГОТОВКИ И ПОВЫШЕНИЯ КВАЛИФИКАЦИИ РАБОТНИКОВ ОБРАЗОВАНИЯ"',
#   10746.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕДЕНТ Ч"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "ЧЕЛЯБИНСКИЙ ИНСТИТУТ ПЕРЕПОДГОТОВКИ И ПОВЫШЕНИЯ КВАЛИФИКАЦИИ РАБОТНИКОВ ОБРАЗОВАНИЯ"',
#   10746.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕДЕНТ Ч"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   27923448.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЕТРА"',
#   '2019'],
#  ['МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ, НАУКИ И ПО ДЕЛАМ МОЛОДЕЖИ КАБАРДИНО-БАЛКАРСКОЙ РЕСПУБЛИКИ',
#   3256200.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СЕЛЕНА"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   5065800.18,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕНТА"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ КЕМЕРОВСКОЙ ОБЛАСТИ',
#   104174784.0,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РОСТЕЛЕКОМ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ТЮМЕНСКОЙ ОБЛАСТИ "ЦЕНТР ИНФОРМАЦИОННЫХ ТЕХНОЛОГИЙ ТЮМЕНСКОЙ ОБЛАСТИ"',
#   102336.0,
#   'Публичное акционерное общество "Ростелеком"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ РЕСПУБЛИКИ МОРДОВИЯ',
#   18063880.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СМАРТ ГРУПП"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ТЮМЕНСКОЙ ОБЛАСТИ',
#   84736666.5,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТЛАЙН ПРОЕКТЫ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   3500000.0,
#   'АКЦИОНЕРНОЕ ОБЩЕСТВО "ИРТЕХ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ СЕВЕРНАЯ ОСЕТИЯ-АЛАНИЯ',
#   20147950.2,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНТ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ, НАУКИ И ПО ДЕЛАМ МОЛОДЕЖИ КАБАРДИНО-БАЛКАРСКОЙ РЕСПУБЛИКИ',
#   34580809.9,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КАББАЛКМЕСТПРОМ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#   205983963.44,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АРХАНГЕЛЬСКОЙ ОБЛАСТИ',
#   25379236.15,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АРХАНГЕЛЬСКОЙ ОБЛАСТИ',
#   25379236.15,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТЫВА',
#   18574246.2,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЕХНОТРЕНД"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   3340680.25,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВИТЕХ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   2776989.34,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРИКЛАДНАЯ РОБОТОТЕХНИКА"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   2743453.06,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НАТИСОН"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   2621590.4,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЮПИТЕР"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ КИРОВСКОЙ ОБЛАСТИ',
#   34891850.68,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РОБИТРОН"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   3291070.0,
#   'Общество с ограниченной ответственностью Производственная компания "Робокинетика"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОРОНЕЖСКОЙ ОБЛАСТИ "БОРИСОГЛЕБСКИЙ ТЕХНИКУМ ПРОМЫШЛЕННЫХ И ИНФОРМАЦИОННЫХ ТЕХНОЛОГИЙ"',
#   1807300.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЕРВЫЙ КЛАСС"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОРОНЕЖСКОЙ ОБЛАСТИ "ВОРОНЕЖСКИЙ ЮРИДИЧЕСКИЙ ТЕХНИКУМ"',
#   1807300.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЕРВЫЙ КЛАСС"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   3901151.9,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НАТИСОН"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   35034076.71,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СКАЙСОФТ ВИКТОРИ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   2220307.34,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ " ТОРГОВАЯ ФИРМА " ИНСЭЛ"',
#   '2019'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   1963325.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ «МОБИЛЬНОЕ ЭЛЕКТРОННОЕ ОБРАЗОВАНИЕ»',
#   '2019'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   22216591.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   8899297.27,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ " ТОРГОВАЯ ФИРМА " ИНСЭЛ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ',
#   11737874.72,
#   'ОАО "Ростелеком"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1445993.7,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЛЬЯНСПЛЮС РОСТОВ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОРОНЕЖСКОЙ ОБЛАСТИ "ВОРОНЕЖСКИЙ ГОСУДАРСТВЕННЫЙ ПРОМЫШЛЕННО-ГУМАНИТАРНЫЙ КОЛЛЕДЖ"',
#   1807300.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЕРВЫЙ КЛАСС"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ КЕМЕРОВСКОЙ ОБЛАСТИ',
#   103105800.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТОНИКА"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   8084000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМПАНИЯ ГЭНДАЛЬФ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1722800.05,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛОМО-МИКРОАНАЛИЗ"',
#   '2019'],
#  ['БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ РЕСПУБЛИКИ АЛТАЙ "РЕСПУБЛИКАНСКИЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   600000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИМАЙ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТЫВА',
#   3618561.43,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СКАЙСОФТ ВИКТОРИ"',
#   '2019'],
#  ['БЮДЖЕТНОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОЛОГОДСКОЙ ОБЛАСТИ "ЧЕРЕПОВЕЦКИЙ ХИМИКО-ТЕХНОЛОГИЧЕСКИЙ КОЛЛЕДЖ"',
#   2153451.11,
#   'Общество с ограниченной ответственностью «ЭКТИВ СКУЛ»',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   6000000.0,
#   'Публичное акционерное общество «Ростелеком»',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#   1209856.88,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ТЮМЕНСКОЙ ОБЛАСТИ',
#   1226995.5,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СКАЙСОФТ ВИКТОРИ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   2244113.34,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТЕЛ-ПРО"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   1816032.04,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КИБЕРНЕТИЧЕСКИЕ ТЕХНОЛОГИИ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   1037235.78,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ НАУЧНО-ПРОИЗВОДСТВЕННОЕ ПРЕДПРИЯТИЕ "УЧЕБНАЯ ТЕХНИКА-ПРОФИ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   2020126.41,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМПАНИЯ ГЭНДАЛЬФ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   9183706.0,
#   'Общество с ограничной ответственностью «ВЕНЕТА СИСТЕМ»',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   1430562.55,
#   'Сараева Александра Сергеевна',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   1034812.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ " ТОРГОВАЯ ФИРМА " ИНСЭЛ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   3180000.0,
#   'Общество с ограничной ответственностью «ВЕНЕТА СИСТЕМ»',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ КАРАЧАЕВО-ЧЕРКЕССКОЙ РЕСПУБЛИКИ',
#   12858224.79,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛОГИКА"',
#   '2019'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   9094933.8,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНФОТЕХ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   10000000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕФОРМА"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   173732.67,
#   'Медведев Евгений Сергеевич',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   212100.91,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОРТ-1"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЫСШЕГО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ "АКАДЕМИЯ СОЦИАЛЬНОГО УПРАВЛЕНИЯ"',
#   42000000.0,
#   'ФГБУ "ФИОКО"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ СЕВЕРНАЯ ОСЕТИЯ-АЛАНИЯ',
#   2429546.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНТ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   2514750.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МЕДИА ХОЛДИНГ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   3469500.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТВОЙ СПУТНИК"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ КЕМЕРОВСКОЙ ОБЛАСТИ',
#   5599031.35,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НАПРАВЛЕНИЕ РУ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ СРЕДНЯЯ ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 625 С УГЛУБЛЕННЫМ ИЗУЧЕНИЕМ МАТЕМАТИКИ НЕВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА ИМЕНИ ГЕРОЯ РОССИЙСКОЙ ФЕДЕРАЦИИ В.Е.ДУДКИНА',
#   3276381.08,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "М-КОМПЛЕКТ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ СРЕДНЯЯ ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 625 С УГЛУБЛЕННЫМ ИЗУЧЕНИЕМ МАТЕМАТИКИ НЕВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА ИМЕНИ ГЕРОЯ РОССИЙСКОЙ ФЕДЕРАЦИИ В.Е.ДУДКИНА',
#   1632508.8,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВОРЛД СКС"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТЫВА',
#   432250.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УМИКА"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ КИРОВСКОЙ ОБЛАСТИ',
#   2389388.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕСЕРЧ ЛАБ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ КАРАЧАЕВО-ЧЕРКЕССКОЙ РЕСПУБЛИКИ',
#   13004341.04,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМПОЗИЦИЯ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   2915000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭДУТЕХ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1508916.67,
#   'Медведев Евгений Сергеевич',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   89291.98,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОМЫШЛЕННЫЕ ЭКОЛОГИЧЕСКИЕ ЛАБОРАТОРИИ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   494325.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НЬЮ ВИЖН ГРУПП"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   2387079.07,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОМЫШЛЕННЫЕ ЭКОЛОГИЧЕСКИЕ ЛАБОРАТОРИИ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ БУРЯТИЯ',
#   47797558.62,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "БЕРКУТ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   7158409.23,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМПОЗА"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   280594.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕЛЕС"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АСТРАХАНСКОЙ ОБЛАСТИ',
#   25781740.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНТ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1902249.99,
#   'Кравченко Михаил Владимирович',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   776900.0,
#   'Общество с ограниченной ответственностью «ИННОВАЦИОННОЕ ПРОИЗВОДСТВО»',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   732587.33,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АРЕНА ПИТЕР"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   439216.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КЛЕВЕР БРАЗЕРС"',
#   '2019'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   905678.44,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНФОТЕХ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   26290233.33,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТВОЙ СПУТНИК"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   15226091.52,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТВОЙ СПУТНИК"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   287491.13,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КЛЕВЕР БРАЗЕРС"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   2156000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМБИ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ СРЕДНЯЯ ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 469 ВЫБОРГСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   6662379.24,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЭКО-СЕРВИС"',
#   '2019'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   1280471.87,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВБК ЦЕНТР"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   125740.0,
#   'Манжин Александр Игоревич',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   1242151.4,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОМЫШЛЕННАЯ МЕБЕЛЬ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   4652700.0,
#   'Общество с ограниченной ответственностью «ТВ Эксперт»',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   187308.16,
#   'Общество с ограниченной ответственностью "СТАНКОПРОМ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ СРЕДНЯЯ ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 469 ВЫБОРГСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   8558719.09,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЭКО-СЕРВИС"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ИРКУТСКОЙ ОБЛАСТИ',
#   86703804.0,
#   'Общество с ограниченной ответственностью "Галилео"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ КАРАЧАЕВО-ЧЕРКЕССКОЙ РЕСПУБЛИКИ',
#   1607278.96,
#   'ЧЖАО АНДРЕЙ ОЛЕГОВИЧ',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   11300000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛАБОРАТОРИЯ ИННОВАЦИЙ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ИРКУТСКОЙ ОБЛАСТИ',
#   865504.49,
#   'Общество с ограниченной ответственностью "Ультра-Ангарск"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЫСШЕГО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ "АКАДЕМИЯ СОЦИАЛЬНОГО УПРАВЛЕНИЯ"',
#   20000000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОФИЛУМ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОРОНЕЖСКОЙ ОБЛАСТИ "БУТУРЛИНОВСКИЙ МЕХАНИКО-ТЕХНОЛОГИЧЕСКИЙ КОЛЛЕДЖ"',
#   1807300.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЕРВЫЙ КЛАСС"',
#   '2019'],
#  ['КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОРОНЕЖСКОЙ ОБЛАСТИ "ГОРОЖАНСКИЙ КАЗАЧИЙ КАДЕТСКИЙ КОРПУС"',
#   2237357.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЕРВЫЙ КЛАСС"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1327863.95,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТАНДЕМ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ СРЕДНЯЯ ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 469 ВЫБОРГСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   3418224.24,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЭКО-СЕРВИС"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   230069.67,
#   'Куркин Виталий Валериевич',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   232609.33,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМПАНИЯ ГЭНДАЛЬФ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1907266.67,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПОЛИМЕДИА-РЕГИОН"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1598763.32,
#   'Кравченко Михаил Владимирович',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ СРЕДНЯЯ ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 625 С УГЛУБЛЕННЫМ ИЗУЧЕНИЕМ МАТЕМАТИКИ НЕВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА ИМЕНИ ГЕРОЯ РОССИЙСКОЙ ФЕДЕРАЦИИ В.Е.ДУДКИНА',
#   15091110.12,
#   'Прохоренко Александр Витальевич',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   16883825.65,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКОМП"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   442862.56,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМПАНИЯ ГЭНДАЛЬФ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   1442900.17,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КЛЕВЕР БРАЗЕРС"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   693056.31,
#   'Кравченко Михаил Владимирович',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   301869.26,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМПАНИЯ ГЭНДАЛЬФ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОРОНЕЖСКОЙ ОБЛАСТИ "ГУБЕРНСКИЙ ПЕДАГОГИЧЕСКИЙ КОЛЛЕДЖ"',
#   1807299.98,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЕРВЫЙ КЛАСС"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ЯРОСЛАВСКОЙ ОБЛАСТИ "АГЕНТСТВО ПО ОБЕСПЕЧЕНИЮ ФУНКЦИОНИРОВАНИЯ СИСТЕМЫ ОБРАЗОВАНИЯ ЯРОСЛАВСКОЙ ОБЛАСТИ"',
#   25365533.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТОРГОВЫЙ ДОМ "ПРОСВЕЩЕНИЕ-РЕГИОН"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ЛИЦЕЙ № 533 "ОБРАЗОВАТЕЛЬНЫЙ КОМПЛЕКС "МАЛАЯ ОХТА" КРАСНОГВАРДЕЙСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   851337.12,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПОЛИМЕДИА-РЕГИОН"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ЯРОСЛАВСКОЙ ОБЛАСТИ "АГЕНТСТВО ПО ОБЕСПЕЧЕНИЮ ФУНКЦИОНИРОВАНИЯ СИСТЕМЫ ОБРАЗОВАНИЯ ЯРОСЛАВСКОЙ ОБЛАСТИ"',
#   2860805.44,
#   'ГАРИФУЛЛИН АЛЕКСЕЙ НАИЛЬЕВИЧ',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   2460000.0,
#   'Общество с ограниченной ответственностью "ДЭФО-Санкт-Петербург"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №261 КИРОВСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   10158562.62,
#   'Борисов Константин Эдуардович',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ КИРОВСКОЙ ОБЛАСТИ',
#   673945.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РОБИТРОН"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ЯРОСЛАВСКОЙ ОБЛАСТИ "АГЕНТСТВО ПО ОБЕСПЕЧЕНИЮ ФУНКЦИОНИРОВАНИЯ СИСТЕМЫ ОБРАЗОВАНИЯ ЯРОСЛАВСКОЙ ОБЛАСТИ"',
#   1715000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЛЬТЕР-М"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   4551821.06,
#   'Индивидуальный предприниматель Шафоростов Алексей Дмитриевич',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АСТРАХАНСКОЙ ОБЛАСТИ',
#   3897600.0,
#   'МАГНАУТДИНОВ СТАНИСЛАВ ЭДУАРДОВИЧ',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   11902104.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕЛЕС"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   964760.4,
#   'Общество с ограниченной ответственностью "ПГК-Белгород"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   19961200.8,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНТ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   4592655.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕЛЕС"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   43074727.5,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЕХНОЛОГИИ БИЗНЕСА"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   391700.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВРОРА С"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ ОБЛАСТНОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "МИНЬКИНСКАЯ КОРРЕКЦИОННАЯ ШКОЛА - ИНТЕРНАТ"',
#   1593780.0,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РОСТЕЛЕКОМ"',
#   '2019'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   230040.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ШИК"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   24779472.5,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМБИ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1307730.6,
#   'Атентьев Олег Владимирович',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ГИМНАЗИЯ №116 ПРИМОРСКОГО РАЙОНА САНКТ-ПЕТЕРБУРГА',
#   1672655.48,
#   'Атентьев Олег Владимирович',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   1708924.81,
#   'Данилина Ольга Андреевна',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   12994999.999999998,
#   'Акционерное общество "ИРТех"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   32293497.83,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРИОРИТЕТ"',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "ПРЕЗИДЕНТСКИЙ ФИЗИКО-МАТЕМАТИЧЕСКИЙ ЛИЦЕЙ № 239"',
#   2108727.32,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРИОРИТЕТ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ КИРОВСКОЙ ОБЛАСТИ',
#   0.0,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РОСТЕЛЕКОМ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   4000000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИРСОФТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТЫВА',
#   1568800.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РУСКО"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТЫВА',
#   212131725.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   81400.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НЬЮ ВИЖН ГРУПП"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   1852557.8,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НОВА"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   425300.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НЬЮ ВИЖН ГРУПП"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ ОРЛОВСКОЙ ОБЛАСТИ',
#   74863150.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "123 СОЛЮШНС"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА И ИНФОРМАТИЗАЦИИ ОБРАЗОВАНИЯ"',
#   2700390.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИРСОФТ"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   688000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НОВА"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   55123.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕСУРС-МЕДИА"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   28611.0,
#   'Индивидуальный предприниматель ГОЗИЕВ МУХАМАДЖОН СУХРОБОВИЧ',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ МУРМАНСКОЙ ОБЛАСТИ',
#   24170880.0,
#   'Мурманский филиал Публичного акционерного общества "Ростелеком"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ МУРМАНСКОЙ ОБЛАСТИ',
#   4087992.0,
#   'ЗАКРЫТОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РЭЙС ТЕЛЕКОМ"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   955512.8,
#   'ИНДИВИДУАЛЬНЫЙ ПРЕДПРИНИМАТЕЛЬ ФОМИЧЕВ МАКСИМ ВЛАДИМИРОВИЧ',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   120948976.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЛС ГРУПП"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ ОРЛОВСКОЙ ОБЛАСТИ',
#   52655400.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТИ ПРОЕКТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ИРКУТСКОЙ ОБЛАСТИ',
#   99403480.0,
#   'Общество с ограниченной ответственностью «Солитон»',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   25971750.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СКАЙСОФТ ВИКТОРИ"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   174825.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОМПЬЮТЕРЫ ЭЛСИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АЛТАЙСКОГО КРАЯ',
#   1686812.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДИАЛ ГРУПП"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   6000000.0,
#   'Автономная некоммерческая организация дополнительного профессионального образования «СофтЛайн Эдюкейшн»',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ КУЗБАССА',
#   217726460.83,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНТЕРЬЕР ОФИС+"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   15285425.36,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   15376356.34,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   5282892.72,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   13554567.16,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   14985425.36,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   14596781.7,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   15185034.51,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   15283034.51,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   15287712.68,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   14600308.77,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   4554044.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НОВА"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   133000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕСУРС-МЕДИА"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "НЕНЕЦКАЯ СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ШКОЛА-ИНТЕРНАТ"',
#   2269176.13,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ОРИОН"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   200000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНСТИТУТ РАЗВИТИЯ ПЕРСОНИФИЦИРОВАННЫХ СИСТЕМ УПРАВЛЕНИЯ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА И ИНФОРМАТИЗАЦИИ ОБРАЗОВАНИЯ"',
#   30800.0,
#   'Коузова Елена Александровна',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   15487712.68,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   16922377.17,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЛЬТЕР-М"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   952899.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕПЛИКАТОР"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   740684.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НЬЮ ВИЖН ГРУПП"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА И ИНФОРМАТИЗАЦИИ ОБРАЗОВАНИЯ"',
#   30800.0,
#   'Маркина Евгения Ивановна',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ЛИПЕЦКОЙ ОБЛАСТИ',
#   12987452.89,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ИРКУТСКОЙ ОБЛАСТИ',
#   17982993.2,
#   'Общество с ограниченной ответственностью «Солитон»',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ИРКУТСКОЙ ОБЛАСТИ',
#   17982993.2,
#   'Общество с ограниченной ответственностью «Солитон»',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕЦКОГО АВТОНОМНОГО ОКРУГА "РЕГИОНАЛЬНЫЙ ЦЕНТР ОЦЕНКИ КАЧЕСТВА ОБРАЗОВАНИЯ"',
#   2200000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АБИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ РЕСПУБЛИКИ МОРДОВИЯ',
#   47739414.96,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ ОРЛОВСКОЙ ОБЛАСТИ',
#   1219920.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕЗОНАНС-М"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ ПРОФЕССИОНАЛЬНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ТУЛЬСКОЙ ОБЛАСТИ "ТУЛЬСКИЙ КОЛЛЕДЖ СТРОИТЕЛЬСТВА И ОТРАСЛЕВЫХ ТЕХНОЛОГИЙ"',
#   397580.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГЛОБАЛТЕК"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АМУРСКОЙ ОБЛАСТИ',
#   1341442.05,
#   'Хадыко Эдуард Гургенович',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ АДЫГЕЯ',
#   203099383.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТОРГОВЫЙ ДОМ "ПРОСВЕЩЕНИЕ-РЕГИОН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   18196104.45,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   15404961.45,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   11139290.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   1077646.89,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВОЛГА ДОКУМЕНТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   15400617.13,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   18046572.09,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   17195318.73,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   17195318.73,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   17195318.73,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЛАДИМИРСКОЙ ОБЛАСТИ "ОМОФОРОВСКАЯ СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА-ИНТЕРНАТ"',
#   2245084.0,
#   'БАРАНОВА АННА АНДРЕЕВНА',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ КАЛИНИНГРАДСКОЙ ОБЛАСТИ ПРОФЕССИОНАЛЬНАЯ ОБРАЗОВАТЕЛЬНАЯ ОРГАНИЗАЦИЯ "ПЕДАГОГИЧЕСКИЙ КОЛЛЕДЖ"',
#   1366803.9,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВЕСТМАСТЕР"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#   230435656.2,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТОРГОВЫЙ ДОМ "ПРОСВЕЩЕНИЕ-РЕГИОН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ИРКУТСКОЙ ОБЛАСТИ',
#   92162840.15,
#   'Общество с ограниченной ответственностью «Лафайет»',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   19553473.23,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОНСТАНТА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   13182720.88,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СПЕЦКОМПЛЕКТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   19460208.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СПЕЦКОМПЛЕКТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ САМАРСКОЙ ОБЛАСТИ',
#   19449665.68,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОНСТАНТА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ УЛЬЯНОВСКОЙ ОБЛАСТИ',
#   1693305.98,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТИ ГРУПП"',
#   '2020'],
#  ['КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОРОНЕЖСКОЙ ОБЛАСТИ "БОРИСОГЛЕБСКИЙ КАДЕТСКИЙ КОРПУС"',
#   962545.57,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЕРВЫЙ КЛАСС"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   228176428.51,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГУД АЙТИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   11500000.0,
#   'Общество с ограниченной ответственностью "Интегрированные компьютерные системы "',
#   '2019'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "ЧЕЛЯБИНСКИЙ ИНСТИТУТ ПЕРЕПОДГОТОВКИ И ПОВЫШЕНИЯ КВАЛИФИКАЦИИ РАБОТНИКОВ ОБРАЗОВАНИЯ"',
#   2876.3,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНМАШКОМПЛЕКТ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "ЧЕЛЯБИНСКИЙ ИНСТИТУТ ПЕРЕПОДГОТОВКИ И ПОВЫШЕНИЯ КВАЛИФИКАЦИИ РАБОТНИКОВ ОБРАЗОВАНИЯ"',
#   2876.3,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНМАШКОМПЛЕКТ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "ЧЕЛЯБИНСКИЙ ИНСТИТУТ ПЕРЕПОДГОТОВКИ И ПОВЫШЕНИЯ КВАЛИФИКАЦИИ РАБОТНИКОВ ОБРАЗОВАНИЯ"',
#   2876.3,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНМАШКОМПЛЕКТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ КАЛМЫКИЯ',
#   5838007.28,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЮНИТРЕЙД"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ СЕВЕРНАЯ ОСЕТИЯ-АЛАНИЯ',
#   139412509.86,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СЕЛЕНА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ РОССИЙСКОЙ ФЕДЕРАЦИИ',
#   98890000.0,
#   'ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЫСШЕГО ОБРАЗОВАНИЯ "РОССИЙСКАЯ АКАДЕМИЯ НАРОДНОГО ХОЗЯЙСТВА И ГОСУДАРСТВЕННОЙ СЛУЖБЫ ПРИ ПРЕЗИДЕНТЕ РОССИЙСКОЙ ФЕДЕРАЦИИ"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ КАЛМЫКИЯ',
#   12150000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛОГИКА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АЛТАЙСКОГО КРАЯ',
#   59002903.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "БИЗНЕС ТРЕЙД"',
#   '2020'],
#  ['ОБЛАСТНОЕ ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ "МОРЯКОВСКАЯ ШКОЛА-ИНТЕРНАТ ДЛЯ ДЕТЕЙ-СИРОТ И ДЕТЕЙ,ОСТАВШИХСЯ БЕЗ ПОПЕЧЕНИЯ РОДИТЕЛЕЙ,С ОГРАНИЧЕННЫМИ ВОЗМОЖНОСТЯМИ ЗДОРОВЬЯ"',
#   840882.8,
#   'ООО "АЙТИ АЛЬФА"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ЯРОСЛАВСКОЙ ОБЛАСТИ "АГЕНТСТВО ПО ОБЕСПЕЧЕНИЮ ФУНКЦИОНИРОВАНИЯ СИСТЕМЫ ОБРАЗОВАНИЯ ЯРОСЛАВСКОЙ ОБЛАСТИ"',
#   1217536.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СМАРТ-ПРИНТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТАТАРСТАН',
#   7605159.12,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНФОРМФИНАНССЕРВИС"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТАТАРСТАН',
#   20706100.74,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙСИЭЛ ТЕХНО"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЛАДИМИРСКОЙ ОБЛАСТИ "СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА-ИНТЕРНАТ Г. КОВРОВ"',
#   3352914.43,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СМАРТ КУБ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЛАДИМИРСКОЙ ОБЛАСТИ "ФОМИНСКАЯ СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА-ИНТЕРНАТ"',
#   514836.64,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГЛОБИНТЕК"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   57891.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТИМ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   845149.89,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТИМ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   876430.06,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТИМ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   9102500.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙТИМ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ СПЕЦИАЛЬНОЕ (КОРРЕКЦИОННОЕ) ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ДЛЯ ОБУЧАЮЩИХСЯ С ОГРАНИЧЕННЫМИ ВОЗМОЖНОСТЯМИ ЗДОРОВЬЯ ВЛАДИМИРСКОЙ ОБЛАСТИ "РАТИСЛОВСКАЯ СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА-ИНТЕРНАТ"',
#   2245082.0,
#   'БАРАНОВА АННА АНДРЕЕВНА',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   25000000.0,
#   'Общество с ограниченной ответственностью "Физикон Лаб"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АРХАНГЕЛЬСКОЙ ОБЛАСТИ',
#   95628257.5,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МЕГАБИТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АРХАНГЕЛЬСКОЙ ОБЛАСТИ',
#   95628257.5,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МЕГАБИТ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЛАДИМИРСКОЙ ОБЛАСТИ "СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА-ИНТЕРНАТ Г.КАМЕШКОВО"',
#   1754414.13,
#   'БАРАНОВА АННА АНДРЕЕВНА',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АЛТАЙСКОГО КРАЯ',
#   8632013.4,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНЖЕНЕРНЫЕ СИСТЕМЫ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТАТАРСТАН',
#   49120344.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЙСИЭЛ ТЕХНО"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ТАТАРСТАН',
#   60250764.6,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВРЕМЯ" КОМПЛЕКСНЫЙ СЕРВИС',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#   1640870.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНТЕГРА-ЦЕНТР"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ УДМУРТСКОЙ РЕСПУБЛИКИ',
#   1571210.36,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЗЕОН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АМУРСКОЙ ОБЛАСТИ',
#   9669163.36,
#   '"Топ ресурс"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   966114.1,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ ТОРГОВАЯ КОМПАНИЯ "ШКОЛЬНАЯ-ЛИГА"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЛАДИМИРСКОЙ ОБЛАСТИ "ГУСЬ-ХРУСТАЛЬНАЯ СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА - ИНТЕРНАТ"',
#   2780641.29,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГЛОБИНТЕК"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АЛТАЙСКОГО КРАЯ',
#   3491825.14,
#   'ПОЛЬСКОЙ ВАСИЛИЙ ВАСИЛЬЕВИЧ -',
#   '2020'],
#  ['КОМИТЕТ ПО ОБРАЗОВАНИЮ ПСКОВСКОЙ ОБЛАСТИ',
#   86392635.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИСТЕМНЫЕ РЕШЕНИЯ"',
#   '2020'],
#  ['КОМИТЕТ ПО ОБРАЗОВАНИЮ ПСКОВСКОЙ ОБЛАСТИ',
#   66235213.87,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВОЛШЕБНЫЙ МИР КОМПЬЮТЕРОВ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ СЕВЕРНАЯ ОСЕТИЯ-АЛАНИЯ',
#   9641967.9,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛОГИКА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   20000000.0,
#   'Общество с ограниченной ответственностью "Физикон Лаб"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   382786.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЕХНОЛОГИИ МАШИН"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   8818799.8,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЕХНОЛОГИИ МАШИН"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   1305262.47,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ ФИРМА "АНТАРЕС"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ ЧЕЧЕНСКОЙ РЕСПУБЛИКИ',
#   11531811.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНТЕГРА-ЦЕНТР"',
#   '2020'],
#  ['КОМИТЕТ ПО ОБРАЗОВАНИЮ ПСКОВСКОЙ ОБЛАСТИ',
#   3132178.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ " ФОРМОЗА-СЕРВИС"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ, НАУКИ И МОЛОДЕЖНОЙ ПОЛИТИКИ РЕСПУБЛИКИ КОМИ',
#   1355000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭР-СИ ГРУПП"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ПЕНЗЕНСКОЙ ОБЛАСТИ',
#   227035581.59,
#   'Акционерное Общество «Научно-производственное предприятие «Рубин»',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЛАДИМИРСКОЙ ОБЛАСТИ ДЛЯ ДЕТЕЙ-СИРОТ И ДЕТЕЙ, ОСТАВШИХСЯ БЕЗ ПОПЕЧЕНИЯ РОДИТЕЛЕЙ, "ЛУХТОНОВСКАЯ СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА-ИНТЕРНАТ"',
#   960549.06,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГЛОБИНТЕК"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ СМОЛЕНСКОЙ ОБЛАСТИ ПО ОБРАЗОВАНИЮ И НАУКЕ',
#   14941788.24,
#   'Северо-Западный филиал ПАО «МегаФон»',
#   '2020'],
#  ['ДЕПАРТАМЕНТ СМОЛЕНСКОЙ ОБЛАСТИ ПО ОБРАЗОВАНИЮ И НАУКЕ',
#   25089495.39,
#   'Северо-Западный филиал ПАО «МегаФон»',
#   '2020'],
#  ['ДЕПАРТАМЕНТ СМОЛЕНСКОЙ ОБЛАСТИ ПО ОБРАЗОВАНИЮ И НАУКЕ',
#   23039605.33,
#   'Северо-Западный филиал ПАО «МегаФон»',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   1899417.54,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОЛИТОН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ И ВОСПИТАНИЯ УЛЬЯНОВСКОЙ ОБЛАСТИ',
#   116430207.78,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РУССКИЕ ПРОГРАММЫ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АМУРСКОЙ ОБЛАСТИ',
#   123633045.62,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДАЛЬНЕВОСТОЧНЫЙ ЦЕНТР ИННОВАЦИОННОГО ОБРАЗОВАНИЯ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АМУРСКОЙ ОБЛАСТИ',
#   19650473.31,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДАЛЬНЕВОСТОЧНЫЙ ЦЕНТР ИННОВАЦИОННОГО ОБРАЗОВАНИЯ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ БУРЯТИЯ',
#   1317652.59,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНТЕРАКТИВНАЯ БУРЯТИЯ"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ СМОЛЕНСКОЙ ОБЛАСТИ ПО ОБРАЗОВАНИЮ И НАУКЕ',
#   17959791.57,
#   'Северо-Западный филиал ПАО «МегаФон»',
#   '2020'],
#  ['ДЕПАРТАМЕНТ СМОЛЕНСКОЙ ОБЛАСТИ ПО ОБРАЗОВАНИЮ И НАУКЕ',
#   17828266.5,
#   'Северо-Западный филиал ПАО «МегаФон»',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АСТРАХАНСКОЙ ОБЛАСТИ',
#   777896.93,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОЛИБРИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ДАГЕСТАН',
#   1521997.23,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИННОВАЦИИ, ТЕХНОЛОГИИ И КОНСАЛТИНГ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   1791000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГЛАДИУС ТРЕЙДИНГ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ БАШКОРТОСТАН',
#   1936769.95,
#   'Общество с ограниченной ответственностью "РЕСУРС"',
#   '2020'],
#  ['МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ И ВОСПИТАНИЯ УЛЬЯНОВСКОЙ ОБЛАСТИ',
#   10998276.87,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕГИОНКОМСЕРВИС"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ДАГЕСТАН',
#   243286550.52,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГУД АЙТИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ РЕСПУБЛИКИ МОРДОВИЯ',
#   22318835.0,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "МЕГАФОН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ УДМУРТСКОЙ РЕСПУБЛИКИ',
#   44939900.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЗЕОН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ, НАУКИ И МОЛОДЕЖНОЙ ПОЛИТИКИ РЕСПУБЛИКИ КОМИ',
#   928530.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МОНТЕГРАЦИЯ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АЛТАЙСКОГО КРАЯ',
#   97317295.28,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "МЕГАФОН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ КИРОВСКОЙ ОБЛАСТИ',
#   162367506.84,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РОБИТРОН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ БУРЯТИЯ',
#   131280529.6,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭКТИВ СКУЛ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ',
#   28270754.44,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО «РОСТЕЛЕКОМ» (Сахалинский филиал)',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ КАРАЧАЕВО-ЧЕРКЕССКОЙ РЕСПУБЛИКИ',
#   29278157.48,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНКОМ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ КАРАЧАЕВО-ЧЕРКЕССКОЙ РЕСПУБЛИКИ',
#   142938642.08,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНКОМ"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ЧУКОТСКОГО АВТОНОМНОГО ОКРУГА',
#   14913624.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЕЗОНА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   127147000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "123 СОЛЮШНС"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   33827064.88,
#   'Поволжский филиал ПАО «МегаФон»',
#   '2020'],
#  ['ДЕПАРТАМЕНТ СМОЛЕНСКОЙ ОБЛАСТИ ПО ОБРАЗОВАНИЮ И НАУКЕ',
#   33088309.02,
#   'Общество с ограниченной ответственностью "ЦентрЭлектроСвязь"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   237000000.0,
#   'Общество с ограниченной ответственностью "Национальный центр информатизации"',
#   '2019'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   185500000.0,
#   'ПАО "Ростелеком"',
#   '2019'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ЧУКОТСКОГО АВТОНОМНОГО ОКРУГА',
#   66038309.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ',
#   36154303.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИНТО"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ',
#   118797476.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МИДЛЕН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ УДМУРТСКОЙ РЕСПУБЛИКИ',
#   37860929.28,
#   'Публичное акционерное общество "МегаФон""',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ КИРОВСКОЙ ОБЛАСТИ',
#   67957702.29,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РОБИТРОН"',
#   '2020'],
#  ['КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВОРОНЕЖСКОЙ ОБЛАСТИ "БОРИСОГЛЕБСКИЙ КАДЕТСКИЙ КОРПУС"',
#   1210552.9,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЕРВЫЙ КЛАСС"',
#   '2020'],
#  ['КОМИТЕТ ОБРАЗОВАНИЯ ЕВРЕЙСКОЙ АВТОНОМНОЙ ОБЛАСТИ',
#   75343120.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИНТО"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ ОРЛОВСКОЙ ОБЛАСТИ',
#   13127239.49,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ТЕХНОЛОГИИ БИЗНЕСА"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ ОБЩЕОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЛАДИМИРСКОЙ ОБЛАСТИ "СПЕЦИАЛЬНАЯ (КОРРЕКЦИОННАЯ) ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА-ИНТЕРНАТ О.МУРОМ"',
#   1882020.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОРТИС-ВЛАДИМИР"',
#   '2020'],
#  ['МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ И ВОСПИТАНИЯ УЛЬЯНОВСКОЙ ОБЛАСТИ',
#   33744756.5,
#   'Публичное акционерное общество «МегаФон»',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ДАГЕСТАН',
#   13895097.52,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИННОВАЦИИ, ТЕХНОЛОГИИ И КОНСАЛТИНГ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ЯРОСЛАВСКОЙ ОБЛАСТИ "АГЕНТСТВО ПО ОБЕСПЕЧЕНИЮ ФУНКЦИОНИРОВАНИЯ СИСТЕМЫ ОБРАЗОВАНИЯ ЯРОСЛАВСКОЙ ОБЛАСТИ"',
#   35887139.19,
#   'Северо-Западный филиал ПАО «МегаФон»',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ БАШКОРТОСТАН',
#   212203367.51,
#   'Общество с ограниченной ответственностью "ЦИФРА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ ХАКАСИЯ',
#   158469890.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕНЕ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АСТРАХАНСКОЙ ОБЛАСТИ',
#   71696070.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ЯРОСЛАВСКОЙ ОБЛАСТИ "АГЕНТСТВО ПО ОБЕСПЕЧЕНИЮ ФУНКЦИОНИРОВАНИЯ СИСТЕМЫ ОБРАЗОВАНИЯ ЯРОСЛАВСКОЙ ОБЛАСТИ"',
#   102044550.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "БАЙТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АРХАНГЕЛЬСКОЙ ОБЛАСТИ',
#   31662000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГУД АЙТИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АРХАНГЕЛЬСКОЙ ОБЛАСТИ',
#   31662000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГУД АЙТИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОМСКОЙ ОБЛАСТИ',
#   207990356.64000002,
#   'ООО "Скай Ай Ти"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ СВЕРДЛОВСКОЙ ОБЛАСТИ "ХОЗЯЙСТВЕННО-ЭКСПЛУАТАЦИОННОЕ УПРАВЛЕНИЕ МИНИСТЕРСТВА ОБРАЗОВАНИЯ И МОЛОДЕЖНОЙ ПОЛИТИКИ СВЕРДЛОВСКОЙ ОБЛАСТИ"',
#   222472036.75,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НАУЧНО-ПРОИЗВОДСТВЕННЫЙ ЦЕНТР "ПРОСВЕЩЕНИЕ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ РЕСПУБЛИКИ МОРДОВИЯ',
#   61074532.8,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦИФРА"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ, НАУКИ И МОЛОДЕЖНОЙ ПОЛИТИКИ РЕСПУБЛИКИ КОМИ',
#   226035.43,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВРОРА С"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ',
#   3143509.32,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО «РОСТЕЛЕКОМ» (Сахалинский филиал)',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ, НАУКИ И МОЛОДЕЖНОЙ ПОЛИТИКИ РЕСПУБЛИКИ КОМИ',
#   5288216.91,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПЯТОЕ ИЗМЕРЕНИЕ"',
#   '2020'],
#  ['ГОСУДАРСТВЕННОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ ЯРОСЛАВСКОЙ ОБЛАСТИ "АГЕНТСТВО ПО ОБЕСПЕЧЕНИЮ ФУНКЦИОНИРОВАНИЯ СИСТЕМЫ ОБРАЗОВАНИЯ ЯРОСЛАВСКОЙ ОБЛАСТИ"',
#   22589465.07,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КРЕМЛЬ 2"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ТВЕРСКОЙ ОБЛАСТИ',
#   167912713.74,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ «РП»',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ УДМУРТСКОЙ РЕСПУБЛИКИ',
#   104133579.26,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДЕЛЬТА ИНВЕСТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ БАШКОРТОСТАН',
#   4489482.75,
#   'Якушина Мария Андреевна',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АМУРСКОЙ ОБЛАСТИ',
#   1152521.8,
#   '"СПЕЦ - МЕБЕЛЬ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ, НАУКИ И МОЛОДЕЖНОЙ ПОЛИТИКИ РЕСПУБЛИКИ КОМИ',
#   512742.48,
#   'РУБЦОВ СЕРГЕЙ ИВАНОВИЧ',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ',
#   5950214.07,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО «РОСТЕЛЕКОМ» (Сахалинский филиал)',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   6980490.0,
#   'Акционерное общество "ИРТех"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   862350.78,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УК ЛН"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   56460.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОГРАМОС-ПРОЕКТЫ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   9776250.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГОСУДАРСТВО ДЕТЕЙ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   36500000.0,
#   'Общество с ограниченной ответственностью "Интегрированные компьютерные системы "',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ ОРЛОВСКОЙ ОБЛАСТИ',
#   5127200.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СЕА-ГРУПП"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ БАШКОРТОСТАН',
#   1286368.2,
#   'Общество с ограниченной ответственностью «ТЕХСЭЙЛ»',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ, НАУКИ И МОЛОДЕЖНОЙ ПОЛИТИКИ РЕСПУБЛИКИ КОМИ',
#   620037.61,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГАЛИЛЕО"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ БАШКОРТОСТАН',
#   3172000.0,
#   'Зубова Екатерина Дмитриевна',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   1800000.0,
#   'АВТОНОМНАЯ НЕКОММЕРЧЕСКАЯ ОРГАНИЗАЦИЯ ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ "ТЮМЕНСКИЙ МЕЖРЕГИОНАЛЬНЫЙ ЦЕНТР АТТЕСТАЦИИ ПЕРСОНАЛА"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ И НАУКИ ГОРОДА СЕВАСТОПОЛЯ',
#   154324093.87,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МЕРКУРИЙ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ТВЕРСКОЙ ОБЛАСТИ',
#   16527445.08,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НАУЧНЫЙ ЦЕНТР "ПОЛЮС"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ТВЕРСКОЙ ОБЛАСТИ',
#   16527445.08,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "НАУЧНЫЙ ЦЕНТР "ПОЛЮС"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ МУРМАНСКОЙ ОБЛАСТИ',
#   2698359.48,
#   'ЗАКРЫТОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РЭЙС ТЕЛЕКОМ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ УДМУРТСКОЙ РЕСПУБЛИКИ',
#   40000000.0,
#   'Общество с ограниченной ответственностью "Ремстрой"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ МУРМАНСКОЙ ОБЛАСТИ',
#   21528000.0,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РОСТЕЛЕКОМ"',
#   '2020'],
#  ['УПРАВЛЕНИЕ ОБРАЗОВАНИЯ И НАУКИ ТАМБОВСКОЙ ОБЛАСТИ',
#   691999.99,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВИРТУАЛИЗАЦИЯ ИТ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ РОССИЙСКОЙ ФЕДЕРАЦИИ',
#   7800000.0,
#   'АКЦИОНЕРНОЕ ОБЩЕСТВО "МИХАЙЛОВ И ПАРТНЕРЫ. УПРАВЛЕНИЕ СТРАТЕГИЧЕСКИМИ КОММУНИКАЦИЯМИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   1199250.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОГРАМОС-ПРОЕКТЫ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ РЕСПУБЛИКИ АЛТАЙ',
#   1500000.0,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "РОСТЕЛЕКОМ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ ОРЕНБУРГСКОЙ ОБЛАСТИ',
#   6005208.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОФТ РЕШЕНИЯ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ, НАУКИ И МОЛОДЕЖНОЙ ПОЛИТИКИ РЕСПУБЛИКИ КОМИ',
#   2900313.38,
#   'СПИРИН АЛЕКСЕЙ ВАЛЕРЬЕВИЧ',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   1751772.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНФИНОР ИНТЕГРАЦИЯ"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   43431799.75,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЛС ГРУПП"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   14668638.25,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭЛПО - СЕРВИС"',
#   '2020'],
#  ['ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ',
#   31703980.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЛЛС ГРУПП"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   142000000.0,
#   'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИБС ЭКСПЕРТИЗА"',
#   '2019'],
#  ['МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ РОССИЙСКОЙ ФЕДЕРАЦИИ',
#   70000000.0,
#   'АКЦИОНЕРНОЕ ОБЩЕСТВО "МИХАЙЛОВ И ПАРТНЕРЫ. УПРАВЛЕНИЕ СТРАТЕГИЧЕСКИМИ КОММУНИКАЦИЯМИ"',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ',
#   34803220.9,
#   'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО «РОСТЕЛЕКОМ» (Сахалинский филиал)',
#   '2021'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АСТРАХАНСКОЙ ОБЛАСТИ',
#   23598694.47,
#   'Публичное акционерное общество «Мегафон»',
#   '2020'],
#  ['МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ',
#   189555171.42999998,
#   'АКЦИОНЕРНОЕ ОБЩЕСТВО "РТ ЛАБС"',
#   '2020']]

# %%
frame = pd.DataFrame(contracts_tab)

# %%
frame
# Out:
#                                                      0  ...     3
# 0         ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ  ...  2019
# 1         ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ  ...  2019
# 2         ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ  ...  2019
# 3    ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕ...  ...  2019
# 4         ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ  ...  2019
# ..                                                 ...  ...   ...
# 349        МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ  ...  2019
# 350      МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ РОССИЙСКОЙ ФЕДЕРАЦИИ  ...  2020
# 351       МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ  ...  2021
# 352  МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АСТРАХАНСКОЙ ...  ...  2020
# 353        МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ  ...  2020
#
# [354 rows x 4 columns]

# %%
frame.rename(columns={0: 'Заказчик', 1: 'Стоимость_оборудования', 2: 'Поставщик', 3: 'Год'}, inplace=True)

# %%
frame
# Out:
#                                               Заказчик  ...   Год
# 0         ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ  ...  2019
# 1         ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ  ...  2019
# 2         ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ  ...  2019
# 3    ГОСУДАРСТВЕННОЕ КАЗЁННОЕ УЧРЕЖДЕНИЕ ЯМАЛО-НЕНЕ...  ...  2019
# 4         ДЕПАРТАМЕНТ ОБРАЗОВАНИЯ БЕЛГОРОДСКОЙ ОБЛАСТИ  ...  2019
# ..                                                 ...  ...   ...
# 349        МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ  ...  2019
# 350      МИНИСТЕРСТВО ПРОСВЕЩЕНИЯ РОССИЙСКОЙ ФЕДЕРАЦИИ  ...  2020
# 351       МИНИСТЕРСТВО ОБРАЗОВАНИЯ САХАЛИНСКОЙ ОБЛАСТИ  ...  2021
# 352  МИНИСТЕРСТВО ОБРАЗОВАНИЯ И НАУКИ АСТРАХАНСКОЙ ...  ...  2020
# 353        МИНИСТЕРСТВО ОБРАЗОВАНИЯ МОСКОВСКОЙ ОБЛАСТИ  ...  2020
#
# [354 rows x 4 columns]

# %%
from google.colab import files
with pd.ExcelWriter('contracts.xlsx') as writer:
  frame.to_excel(writer, sheet_name='contracts')
files.download('contracts.xlsx')
